# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaamanikam11/Covid_Vaccine_Analysis/blob/main/NLP_Vaama_New.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow_datasets
# !pip install -U tensorflow-text
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_datasets in /usr/local/lib/python3.7/dist-packages (4.6.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (0.10.2)
# Requirement already satisfied: protobuf>=3.12.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (3.17.3)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (1.10.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (2.3)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (1.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (4.64.1)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (0.7.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (1.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (1.15.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (4.1.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (5.9.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (0.3.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tensorflow_datasets) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tensorflow_datasets) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tensorflow_datasets) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tensorflow_datasets) (2.10)
# Requirement already satisfied: zipp in /usr/local/lib/python3.7/dist-packages (from etils[epath]->tensorflow_datasets) (3.8.1)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-metadata->tensorflow_datasets) (1.56.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-text
#   Downloading tensorflow_text-2.10.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 30.2 MB/s
# Collecting tensorflow<2.11,>=2.10.0
#   Downloading tensorflow-2.10.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (578.0 MB)
#      |████████████████████████████████| 578.0 MB 15 kB/s
# Requirement already satisfied: tensorflow-hub>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-text) (0.12.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (3.3.0)
# Collecting keras<2.11,>=2.10.0
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 58.7 MB/s
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (1.2.0)
# Collecting tensorflow-estimator<2.11,>=2.10.0
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
#      |████████████████████████████████| 438 kB 70.5 MB/s
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (1.14.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (0.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (4.1.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (0.26.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (1.1.2)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (1.21.6)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (3.17.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (2.0.7)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (1.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (57.4.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (3.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (21.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (1.15.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (1.48.1)
# Collecting tensorboard<2.11,>=2.10
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 62.6 MB/s
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (14.0.6)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (1.6.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow<2.11,>=2.10.0->tensorflow-text) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow<2.11,>=2.10.0->tensorflow-text) (1.5.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (1.35.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (2.23.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (3.4.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (3.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow<2.11,>=2.10.0->tensorflow-text) (3.0.9)
# Installing collected packages: tensorflow-estimator, tensorboard, keras, gast, tensorflow, tensorflow-text
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.8.0
#     Uninstalling keras-2.8.0:
#       Successfully uninstalled keras-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.2+zzzcolab20220719082949
#     Uninstalling tensorflow-2.8.2+zzzcolab20220719082949:
#       Successfully uninstalled tensorflow-2.8.2+zzzcolab20220719082949
# Successfully installed gast-0.4.0 keras-2.10.0 tensorboard-2.10.1 tensorflow-2.10.0 tensorflow-estimator-2.10.0 tensorflow-text-2.10.0

# %%
import collections
import logging
import os
import pathlib
import re
import string
import sys
import time

import numpy as np
import matplotlib.pyplot as plt

# %%
import tensorflow_datasets as tfds
import tensorflow_text as text
import tensorflow as tf

# %%
logging.getLogger('tensorflow').setLevel(logging.ERROR)  # suppress warnings

# %%
examples, metadata = tfds.load('ted_hrlr_translate/pt_to_en', with_info=True,
                               as_supervised=True)
train_examples, val_examples = examples['train'], examples['validation']
# Out:
# Downloading and preparing dataset 124.94 MiB (download: 124.94 MiB, generated: Unknown size, total: 124.94 MiB) to ~/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/51785 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0.incomplete71UAE8/ted_hrlr_translate-train.tf…
# Generating validation examples...:   0%|          | 0/1193 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0.incomplete71UAE8/ted_hrlr_translate-validati…
# Generating test examples...:   0%|          | 0/1803 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0.incomplete71UAE8/ted_hrlr_translate-test.tfr…
# Dataset ted_hrlr_translate downloaded and prepared to ~/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0. Subsequent calls will reuse this data.

# %%
model_name = "ted_hrlr_translate_pt_en_converter"
tf.keras.utils.get_file(
    f"{model_name}.zip",
    f"https://storage.googleapis.com/download.tensorflow.org/models/{model_name}.zip",
    cache_dir='.', cache_subdir='', extract=True
)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/models/ted_hrlr_translate_pt_en_converter.zip
# 184801/184801 [==============================] - 0s 0us/step
# './ted_hrlr_translate_pt_en_converter.zip'

# %%
#tokenizers contains both the english and portugese tokenizer,
# with tokenize, detokenize and lookup methods
tokenizers = tf.saved_model.load(model_name)

# %%
def tokenize_pairs(pt, en):
    pt = tokenizers.pt.tokenize(pt)
    # Convert from ragged to dense, padding with zeros.
    pt = pt.to_tensor()
    en = tokenizers.en.tokenize(en)
    # Convert from ragged to dense, padding with zeros.
    en = en.to_tensor()
    return pt, en

# %%
#constants
BUFFER_SIZE = 20000
BATCH_SIZE = 64

# %%
def make_batches(ds):
  return (
      ds
      .cache()
      .shuffle(BUFFER_SIZE)
      .batch(BATCH_SIZE)
      .map(tokenize_pairs, num_parallel_calls=tf.data.AUTOTUNE)
      .prefetch(tf.data.AUTOTUNE))
  
train_batches = make_batches(train_examples)
val_batches = make_batches(val_examples)

# %%
def get_angles(pos, i, d_model):
  angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
  return pos * angle_rates

# %%
def positional_encoding(position, d_model):
  angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)
  # apply sin to even indices in the array; 2i
  angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
  # apply cos to odd indices in the array; 2i+1
  angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
  pos_encoding = angle_rads[np.newaxis, ...]
  return tf.cast(pos_encoding, dtype=tf.float32)

# %%
def create_padding_mask(seq):
  seq = tf.cast(tf.math.equal(seq, 0), tf.float32)
  # add extra dimensions to add the padding
  # to the attention logits.
  return seq[:, tf.newaxis, tf.newaxis, :]  # (batch_size, 1, 1, seq_len)

# %%
def create_look_ahead_mask(size):
  mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
  return mask  # (seq_len, seq_len)

# %%
def scaled_dot_product_attention(q, k, v, mask):
  """Calculate the attention weights
    q: query shape == (..., seq_len_q, depth)
    k: key shape == (..., seq_len_k, depth)
    v: value shape == (..., seq_len_v, depth_v)
    mask: Float tensor with shape broadcastable
          to (..., seq_len_q, seq_len_k). Defaults to None.

    Return: output, attention_weights
  """

  matmul_qk = tf.matmul(q, k, transpose_b=True)  # (..., seq_len_q, seq_len_k)
  dk = tf.cast(tf.shape(k)[-1], tf.float32)
  scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

  # add the mask to the scaled tensor.
  if mask is not None:
    scaled_attention_logits += (mask * -1e9)

  # softmax is normalized on the last axis (seq_len_k) so that the scores
  # add up to 1.
  attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)  # (..., seq_len_q, seq_len_k)

  output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)

  return output, attention_weights

# %%
#helper function to demonstrate attention weight and output on multiplication
def print_out(q, k, v):
  temp_out, temp_attn = scaled_dot_product_attention(
      q, k, v, None)
  print('Attention weights are:')
  print(temp_attn)
  print('Output is:')
  print(temp_out)

# %%
np.set_printoptions(suppress=True)

temp_k = tf.constant([[10, 0, 0],
                      [0, 10, 0],
                      [0, 0, 10],
                      [0, 0, 10]], dtype=tf.float32)  # (4, 3)

temp_v = tf.constant([[1, 0],
                      [10, 0],
                      [100, 5],
                      [1000, 6]], dtype=tf.float32)  # (4, 2)

# %%
# This `query` aligns with the second `key`,
# so the second `value` is returned.
temp_q = tf.constant([[0, 10, 0]], dtype=tf.float32)  # (1, 3)
print_out(temp_q, temp_k, temp_v)
print()

# This query aligns with a repeated key (third and fourth),
# so all associated values get averaged.
temp_q = tf.constant([[0, 0, 10]], dtype=tf.float32)  # (1, 3)
print_out(temp_q, temp_k, temp_v)
print()

# This query aligns equally with the first and second key,
# so their values get averaged.
temp_q = tf.constant([[10, 10, 0]], dtype=tf.float32)  # (1, 3)
print_out(temp_q, temp_k, temp_v)
# Out:
# Attention weights are:
# tf.Tensor([[0. 1. 0. 0.]], shape=(1, 4), dtype=float32)
# Output is:
# tf.Tensor([[10.  0.]], shape=(1, 2), dtype=float32)
#
# Attention weights are:
# tf.Tensor([[0.  0.  0.5 0.5]], shape=(1, 4), dtype=float32)
# Output is:
# tf.Tensor([[550.    5.5]], shape=(1, 2), dtype=float32)
#
# Attention weights are:
# tf.Tensor([[0.5 0.5 0.  0. ]], shape=(1, 4), dtype=float32)
# Output is:
# tf.Tensor([[5.5 0. ]], shape=(1, 2), dtype=float32)

# %%
temp_q = tf.constant([[0, 0, 10],
                      [0, 10, 0],
                      [10, 10, 0]], dtype=tf.float32)  # (3, 3)
print_out(temp_q, temp_k, temp_v)
# Out:
# Attention weights are:
# tf.Tensor(
# [[0.  0.  0.5 0.5]
#  [0.  1.  0.  0. ]
#  [0.5 0.5 0.  0. ]], shape=(3, 4), dtype=float32)
# Output is:
# tf.Tensor(
# [[550.    5.5]
#  [ 10.    0. ]
#  [  5.5   0. ]], shape=(3, 2), dtype=float32)

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads):
    super(MultiHeadAttention, self).__init__()
    self.num_heads = num_heads
    self.d_model = d_model

    assert d_model % self.num_heads == 0

    self.depth = d_model // self.num_heads

    self.wq = tf.keras.layers.Dense(d_model)
    self.wk = tf.keras.layers.Dense(d_model)
    self.wv = tf.keras.layers.Dense(d_model)

    self.dense = tf.keras.layers.Dense(d_model)

  def split_heads(self, x, batch_size):
    """Split the last dimension into (num_heads, depth).
    Transpose the result such that the shape is (batch_size, num_heads, seq_len, depth)
    """
    x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
    return tf.transpose(x, perm=[0, 2, 1, 3])

  def call(self, v, k, q, mask):
    batch_size = tf.shape(q)[0]

    q = self.wq(q)  # (batch_size, seq_len, d_model)
    k = self.wk(k)  # (batch_size, seq_len, d_model)
    v = self.wv(v)  # (batch_size, seq_len, d_model)

    q = self.split_heads(q, batch_size)  # (batch_size, num_heads, seq_len_q, depth)
    k = self.split_heads(k, batch_size)  # (batch_size, num_heads, seq_len_k, depth)
    v = self.split_heads(v, batch_size)  # (batch_size, num_heads, seq_len_v, depth)

    # scaled_attention.shape == (batch_size, num_heads, seq_len_q, depth)
    # attention_weights.shape == (batch_size, num_heads, seq_len_q, seq_len_k)
    scaled_attention, attention_weights = scaled_dot_product_attention(
        q, k, v, mask)

    scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])  # (batch_size, seq_len_q, num_heads, depth)

    concat_attention = tf.reshape(scaled_attention,
                                  (batch_size, -1, self.d_model))  # (batch_size, seq_len_q, d_model)

    output = self.dense(concat_attention)  # (batch_size, seq_len_q, d_model)

    return output, attention_weights

# %%
def point_wise_feed_forward_network(d_model, dff):
  return tf.keras.Sequential([
      tf.keras.layers.Dense(dff, activation='relu'),  # (batch_size, seq_len, dff)
      tf.keras.layers.Dense(d_model)  # (batch_size, seq_len, d_model)
  ])

# %%
class EncoderLayer(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads, dff, rate=0.1):
    super(EncoderLayer, self).__init__()

    self.mha = MultiHeadAttention(d_model, num_heads)
    self.ffn = point_wise_feed_forward_network(d_model, dff)

    self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

    self.dropout1 = tf.keras.layers.Dropout(rate)
    self.dropout2 = tf.keras.layers.Dropout(rate)

  def call(self, x, training, mask):

    attn_output, _ = self.mha(x, x, x, mask)  # (batch_size, input_seq_len, d_model)
    attn_output = self.dropout1(attn_output, training=training)
    out1 = self.layernorm1(x + attn_output)  # (batch_size, input_seq_len, d_model)

    ffn_output = self.ffn(out1)  # (batch_size, input_seq_len, d_model)
    ffn_output = self.dropout2(ffn_output, training=training)
    out2 = self.layernorm2(out1 + ffn_output)  # (batch_size, input_seq_len, d_model)

    return out2

# %%
class DecoderLayer(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads, dff, rate=0.1):
    super(DecoderLayer, self).__init__()

    self.mha1 = MultiHeadAttention(d_model, num_heads)
    self.mha2 = MultiHeadAttention(d_model, num_heads)

    self.ffn = point_wise_feed_forward_network(d_model, dff)

    self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

    self.dropout1 = tf.keras.layers.Dropout(rate)
    self.dropout2 = tf.keras.layers.Dropout(rate)
    self.dropout3 = tf.keras.layers.Dropout(rate)

  def call(self, x, enc_output, training,
           look_ahead_mask, padding_mask):
    # enc_output.shape == (batch_size, input_seq_len, d_model)

    attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)  # (batch_size, target_seq_len, d_model)
    attn1 = self.dropout1(attn1, training=training)
    out1 = self.layernorm1(attn1 + x)

    attn2, attn_weights_block2 = self.mha2(
        enc_output, enc_output, out1, padding_mask)  # (batch_size, target_seq_len, d_model)
    attn2 = self.dropout2(attn2, training=training)
    out2 = self.layernorm2(attn2 + out1)  # (batch_size, target_seq_len, d_model)

    ffn_output = self.ffn(out2)  # (batch_size, target_seq_len, d_model)
    ffn_output = self.dropout3(ffn_output, training=training)
    out3 = self.layernorm3(ffn_output + out2)  # (batch_size, target_seq_len, d_model)

    return out3, attn_weights_block1, attn_weights_block2

# %%
class Encoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size,
               maximum_position_encoding, rate=0.1):
    super(Encoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers

    self.embedding = tf.keras.layers.Embedding(input_vocab_size, d_model)
    self.pos_encoding = positional_encoding(maximum_position_encoding,
                                            self.d_model)

    self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate)
                       for _ in range(num_layers)]

    self.dropout = tf.keras.layers.Dropout(rate)

  def call(self, x, training, mask):

    seq_len = tf.shape(x)[1]

    # adding embedding and position encoding.
    x = self.embedding(x)  # (batch_size, input_seq_len, d_model)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]

    x = self.dropout(x, training=training)

    for i in range(self.num_layers):
      x = self.enc_layers[i](x, training, mask)

    return x  # (batch_size, input_seq_len, d_model)

# %%
class Decoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff, target_vocab_size,
               maximum_position_encoding, rate=0.1):
    super(Decoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers

    self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
    self.pos_encoding = positional_encoding(maximum_position_encoding, d_model)

    self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate)
                       for _ in range(num_layers)]
    self.dropout = tf.keras.layers.Dropout(rate)

  def call(self, x, enc_output, training,
           look_ahead_mask, padding_mask):

    seq_len = tf.shape(x)[1]
    attention_weights = {}

    x = self.embedding(x)  # (batch_size, target_seq_len, d_model)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]

    x = self.dropout(x, training=training)

    for i in range(self.num_layers):
      x, block1, block2 = self.dec_layers[i](x, enc_output, training,
                                             look_ahead_mask, padding_mask)

      attention_weights[f'decoder_layer{i+1}_block1'] = block1
      attention_weights[f'decoder_layer{i+1}_block2'] = block2

    # x.shape == (batch_size, target_seq_len, d_model)
    return x, attention_weights

# %%
class Transformer(tf.keras.Model):
  def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size,
               target_vocab_size, pe_input, pe_target, rate=0.1):
    super().__init__()
    self.encoder = Encoder(num_layers, d_model, num_heads, dff,
                             input_vocab_size, pe_input, rate)

    self.decoder = Decoder(num_layers, d_model, num_heads, dff,
                           target_vocab_size, pe_target, rate)

    self.final_layer = tf.keras.layers.Dense(target_vocab_size)

  def call(self, inputs, training):
    # Keras models prefer if you pass all your inputs in the first argument
    inp, tar = inputs

    enc_padding_mask, look_ahead_mask, dec_padding_mask = self.create_masks(inp, tar)

    enc_output = self.encoder(inp, training, enc_padding_mask)  # (batch_size, inp_seq_len, d_model)

    # dec_output.shape == (batch_size, tar_seq_len, d_model)
    dec_output, attention_weights = self.decoder(
        tar, enc_output, training, look_ahead_mask, dec_padding_mask)

    final_output = self.final_layer(dec_output)  # (batch_size, tar_seq_len, target_vocab_size)

    return final_output, attention_weights

  def create_masks(self, inp, tar):
    # Encoder padding mask
    enc_padding_mask = create_padding_mask(inp)

    # Used in the 2nd attention block in the decoder.
    # This padding mask is used to mask the encoder outputs.
    dec_padding_mask = create_padding_mask(inp)

    # Used in the 1st attention block in the decoder.
    # It is used to pad and mask future tokens in the input received by
    # the decoder.
    look_ahead_mask = create_look_ahead_mask(tf.shape(tar)[1])
    dec_target_padding_mask = create_padding_mask(tar)
    look_ahead_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)

    return enc_padding_mask, look_ahead_mask, dec_padding_mask

# %%
num_layers = 4
d_model = 128
dff = 512
num_heads = 8
dropout_rate = 0.1

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
  def __init__(self, d_model, warmup_steps=4000):
    super(CustomSchedule, self).__init__()

    self.d_model = d_model
    self.d_model = tf.cast(self.d_model, tf.float32)

    self.warmup_steps = warmup_steps

  def __call__(self, step):
    arg1 = tf.math.rsqrt(step)
    arg2 = step * (self.warmup_steps ** -1.5)

    return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

#create the learning rate scheduler and optimizer
learning_rate = CustomSchedule(d_model)
optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98,
                                     epsilon=1e-9)

# %%
#sparse categorical loss since we have scaler labels
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

#loss function helper
def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_sum(loss_)/tf.reduce_sum(mask)

#accuracy function helper
def accuracy_function(real, pred):
  accuracies = tf.equal(real, tf.argmax(pred, axis=2))

  mask = tf.math.logical_not(tf.math.equal(real, 0))
  accuracies = tf.math.logical_and(mask, accuracies)

  accuracies = tf.cast(accuracies, dtype=tf.float32)
  mask = tf.cast(mask, dtype=tf.float32)
  return tf.reduce_sum(accuracies)/tf.reduce_sum(mask)

#instantiate training loss and accuracy metrics
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

# %%
transformer = Transformer(
    num_layers=num_layers,
    d_model=d_model,
    num_heads=num_heads,
    dff=dff,
    input_vocab_size=tokenizers.pt.get_vocab_size().numpy(),
    target_vocab_size=tokenizers.en.get_vocab_size().numpy(),
    pe_input=1000,
    pe_target=1000,
    rate=dropout_rate)

# %%
checkpoint_path = "./checkpoints/train"

ckpt = tf.train.Checkpoint(transformer=transformer,
                           optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# if a checkpoint exists, restore the latest checkpoint.
if ckpt_manager.latest_checkpoint:
  ckpt.restore(ckpt_manager.latest_checkpoint)
  print('Latest checkpoint restored!!')

# %%
EPOCHS = 100

# %%
train_step_signature = [
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
]

@tf.function(input_signature=train_step_signature)
def train_step(inp, tar):
  tar_inp = tar[:, :-1]
  tar_real = tar[:, 1:]

  with tf.GradientTape() as tape:
    predictions, _ = transformer([inp, tar_inp],
                                 training = True)
    loss = loss_function(tar_real, predictions)

  gradients = tape.gradient(loss, transformer.trainable_variables)
  optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))

  train_loss(loss)
  train_accuracy(accuracy_function(tar_real, predictions))

# %%
for epoch in range(EPOCHS):
  start = time.time()

  train_loss.reset_states()
  train_accuracy.reset_states()

  # inp -> portuguese, tar -> english
  for (batch, (inp, tar)) in enumerate(train_batches):
    train_step(inp, tar)

    if batch % 50 == 0:
      print(f'Epoch {epoch + 1} Batch {batch} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

  if (epoch + 1) % 5 == 0:
    ckpt_save_path = ckpt_manager.save()
    print(f'Saving checkpoint for epoch {epoch+1} at {ckpt_save_path}')

  print(f'Epoch {epoch + 1} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

  print(f'Time taken for epoch {epoch+1}: {time.time() - start:.2f} secs\n')
# Out:
# Epoch 1 Batch 0 Loss 8.8786 Accuracy 0.0000
# Epoch 1 Batch 50 Loss 8.8212 Accuracy 0.0024
# Epoch 1 Batch 100 Loss 8.7106 Accuracy 0.0214
# Epoch 1 Batch 150 Loss 8.5927 Accuracy 0.0299
# Epoch 1 Batch 200 Loss 8.4497 Accuracy 0.0344
# Epoch 1 Batch 250 Loss 8.2797 Accuracy 0.0397
# Epoch 1 Batch 300 Loss 8.0882 Accuracy 0.0478
# Epoch 1 Batch 350 Loss 7.8908 Accuracy 0.0571
# Epoch 1 Batch 400 Loss 7.7028 Accuracy 0.0650
# Epoch 1 Batch 450 Loss 7.5336 Accuracy 0.0728
# Epoch 1 Batch 500 Loss 7.3853 Accuracy 0.0803
# Epoch 1 Batch 550 Loss 7.2515 Accuracy 0.0876
# Epoch 1 Batch 600 Loss 7.1240 Accuracy 0.0952
# Epoch 1 Batch 650 Loss 7.0096 Accuracy 0.1020
# Epoch 1 Batch 700 Loss 6.9022 Accuracy 0.1084
# Epoch 1 Batch 750 Loss 6.8023 Accuracy 0.1145
# Epoch 1 Batch 800 Loss 6.7103 Accuracy 0.1202
# Epoch 1 Loss 6.6940 Accuracy 0.1212
# Time taken for epoch 1: 120.85 secs
#
# Epoch 2 Batch 0 Loss 5.3162 Accuracy 0.2008
# Epoch 2 Batch 50 Loss 5.2330 Accuracy 0.2145
# Epoch 2 Batch 100 Loss 5.2064 Accuracy 0.2164
# Epoch 2 Batch 150 Loss 5.1814 Accuracy 0.2189
# Epoch 2 Batch 200 Loss 5.1553 Accuracy 0.2220
# Epoch 2 Batch 250 Loss 5.1287 Accuracy 0.2250
# Epoch 2 Batch 300 Loss 5.1050 Accuracy 0.2269
# Epoch 2 Batch 350 Loss 5.0784 Accuracy 0.2295
# Epoch 2 Batch 400 Loss 5.0567 Accuracy 0.2315
# Epoch 2 Batch 450 Loss 5.0355 Accuracy 0.2335
# Epoch 2 Batch 500 Loss 5.0136 Accuracy 0.2357
# Epoch 2 Batch 550 Loss 4.9900 Accuracy 0.2379
# Epoch 2 Batch 600 Loss 4.9718 Accuracy 0.2394
# Epoch 2 Batch 650 Loss 4.9538 Accuracy 0.2409
# Epoch 2 Batch 700 Loss 4.9348 Accuracy 0.2428
# Epoch 2 Batch 750 Loss 4.9193 Accuracy 0.2440
# Epoch 2 Batch 800 Loss 4.9014 Accuracy 0.2455
# Epoch 2 Loss 4.8996 Accuracy 0.2457
# Time taken for epoch 2: 93.51 secs
#
# Epoch 3 Batch 0 Loss 4.8833 Accuracy 0.2190
# Epoch 3 Batch 50 Loss 4.5958 Accuracy 0.2728
# Epoch 3 Batch 100 Loss 4.6017 Accuracy 0.2711
# Epoch 3 Batch 150 Loss 4.5825 Accuracy 0.2720
# Epoch 3 Batch 200 Loss 4.5673 Accuracy 0.2730
# Epoch 3 Batch 250 Loss 4.5427 Accuracy 0.2762
# Epoch 3 Batch 300 Loss 4.5279 Accuracy 0.2783
# Epoch 3 Batch 350 Loss 4.5094 Accuracy 0.2807
# Epoch 3 Batch 400 Loss 4.4960 Accuracy 0.2821
# Epoch 3 Batch 450 Loss 4.4802 Accuracy 0.2838
# Epoch 3 Batch 500 Loss 4.4673 Accuracy 0.2852
# Epoch 3 Batch 550 Loss 4.4539 Accuracy 0.2870
# Epoch 3 Batch 600 Loss 4.4379 Accuracy 0.2889
# Epoch 3 Batch 650 Loss 4.4227 Accuracy 0.2905
# Epoch 3 Batch 700 Loss 4.4075 Accuracy 0.2925
# Epoch 3 Batch 750 Loss 4.3915 Accuracy 0.2945
# Epoch 3 Batch 800 Loss 4.3760 Accuracy 0.2964
# Epoch 3 Loss 4.3729 Accuracy 0.2967
# Time taken for epoch 3: 94.02 secs
#
# Epoch 4 Batch 0 Loss 3.9795 Accuracy 0.3407
# Epoch 4 Batch 50 Loss 4.0350 Accuracy 0.3357
# Epoch 4 Batch 100 Loss 4.0297 Accuracy 0.3374
# Epoch 4 Batch 150 Loss 4.0097 Accuracy 0.3391
# Epoch 4 Batch 200 Loss 3.9927 Accuracy 0.3409
# Epoch 4 Batch 250 Loss 3.9786 Accuracy 0.3420
# Epoch 4 Batch 300 Loss 3.9630 Accuracy 0.3442
# Epoch 4 Batch 350 Loss 3.9528 Accuracy 0.3456
# Epoch 4 Batch 400 Loss 3.9345 Accuracy 0.3481
# Epoch 4 Batch 450 Loss 3.9171 Accuracy 0.3506
# Epoch 4 Batch 500 Loss 3.9021 Accuracy 0.3523
# Epoch 4 Batch 550 Loss 3.8904 Accuracy 0.3537
# Epoch 4 Batch 600 Loss 3.8759 Accuracy 0.3557
# Epoch 4 Batch 650 Loss 3.8619 Accuracy 0.3577
# Epoch 4 Batch 700 Loss 3.8492 Accuracy 0.3595
# Epoch 4 Batch 750 Loss 3.8360 Accuracy 0.3614
# Epoch 4 Batch 800 Loss 3.8215 Accuracy 0.3632
# Epoch 4 Loss 3.8187 Accuracy 0.3636
# Time taken for epoch 4: 93.66 secs
#
# Epoch 5 Batch 0 Loss 3.8059 Accuracy 0.3548
# Epoch 5 Batch 50 Loss 3.5016 Accuracy 0.4017
# Epoch 5 Batch 100 Loss 3.4847 Accuracy 0.4048
# Epoch 5 Batch 150 Loss 3.4798 Accuracy 0.4046
# Epoch 5 Batch 200 Loss 3.4775 Accuracy 0.4051
# Epoch 5 Batch 250 Loss 3.4700 Accuracy 0.4057
# Epoch 5 Batch 300 Loss 3.4629 Accuracy 0.4066
# Epoch 5 Batch 350 Loss 3.4522 Accuracy 0.4081
# Epoch 5 Batch 400 Loss 3.4426 Accuracy 0.4095
# Epoch 5 Batch 450 Loss 3.4329 Accuracy 0.4106
# Epoch 5 Batch 500 Loss 3.4255 Accuracy 0.4115
# Epoch 5 Batch 550 Loss 3.4162 Accuracy 0.4125
# Epoch 5 Batch 600 Loss 3.4076 Accuracy 0.4136
# Epoch 5 Batch 650 Loss 3.3993 Accuracy 0.4145
# Epoch 5 Batch 700 Loss 3.3921 Accuracy 0.4154
# Epoch 5 Batch 750 Loss 3.3826 Accuracy 0.4166
# Epoch 5 Batch 800 Loss 3.3724 Accuracy 0.4180
# Saving checkpoint for epoch 5 at ./checkpoints/train/ckpt-1
# Epoch 5 Loss 3.3700 Accuracy 0.4184
# Time taken for epoch 5: 94.26 secs
#
# Epoch 6 Batch 0 Loss 3.2499 Accuracy 0.4292
# Epoch 6 Batch 50 Loss 3.0989 Accuracy 0.4480
# Epoch 6 Batch 100 Loss 3.0929 Accuracy 0.4495
# Epoch 6 Batch 150 Loss 3.0870 Accuracy 0.4504
# Epoch 6 Batch 200 Loss 3.0839 Accuracy 0.4510
# Epoch 6 Batch 250 Loss 3.0715 Accuracy 0.4529
# Epoch 6 Batch 300 Loss 3.0646 Accuracy 0.4544
# Epoch 6 Batch 350 Loss 3.0590 Accuracy 0.4550
# Epoch 6 Batch 400 Loss 3.0523 Accuracy 0.4559
# Epoch 6 Batch 450 Loss 3.0428 Accuracy 0.4571
# Epoch 6 Batch 500 Loss 3.0317 Accuracy 0.4588
# Epoch 6 Batch 550 Loss 3.0244 Accuracy 0.4597
# Epoch 6 Batch 600 Loss 3.0188 Accuracy 0.4606
# Epoch 6 Batch 650 Loss 3.0109 Accuracy 0.4617
# Epoch 6 Batch 700 Loss 3.0044 Accuracy 0.4627
# Epoch 6 Batch 750 Loss 2.9971 Accuracy 0.4636
# Epoch 6 Batch 800 Loss 2.9902 Accuracy 0.4647
# Epoch 6 Loss 2.9898 Accuracy 0.4648
# Time taken for epoch 6: 93.25 secs
#
# Epoch 7 Batch 0 Loss 2.6649 Accuracy 0.5184
# Epoch 7 Batch 50 Loss 2.6892 Accuracy 0.5015
# Epoch 7 Batch 100 Loss 2.6896 Accuracy 0.5011
# Epoch 7 Batch 150 Loss 2.6954 Accuracy 0.5019
# Epoch 7 Batch 200 Loss 2.7038 Accuracy 0.5005
# Epoch 7 Batch 250 Loss 2.7021 Accuracy 0.5009
# Epoch 7 Batch 300 Loss 2.6991 Accuracy 0.5011
# Epoch 7 Batch 350 Loss 2.6979 Accuracy 0.5011
# Epoch 7 Batch 400 Loss 2.6894 Accuracy 0.5023
# Epoch 7 Batch 450 Loss 2.6842 Accuracy 0.5029
# Epoch 7 Batch 500 Loss 2.6822 Accuracy 0.5032
# Epoch 7 Batch 550 Loss 2.6792 Accuracy 0.5038
# Epoch 7 Batch 600 Loss 2.6757 Accuracy 0.5044
# Epoch 7 Batch 650 Loss 2.6696 Accuracy 0.5052
# Epoch 7 Batch 700 Loss 2.6660 Accuracy 0.5059
# Epoch 7 Batch 750 Loss 2.6640 Accuracy 0.5062
# Epoch 7 Batch 800 Loss 2.6594 Accuracy 0.5070
# Epoch 7 Loss 2.6588 Accuracy 0.5070
# Time taken for epoch 7: 92.82 secs
#
# Epoch 8 Batch 0 Loss 2.2871 Accuracy 0.5604
# Epoch 8 Batch 50 Loss 2.4465 Accuracy 0.5329
# Epoch 8 Batch 100 Loss 2.4462 Accuracy 0.5331
# Epoch 8 Batch 150 Loss 2.4384 Accuracy 0.5340
# Epoch 8 Batch 200 Loss 2.4439 Accuracy 0.5337
# Epoch 8 Batch 250 Loss 2.4367 Accuracy 0.5354
# Epoch 8 Batch 300 Loss 2.4345 Accuracy 0.5356
# Epoch 8 Batch 350 Loss 2.4324 Accuracy 0.5359
# Epoch 8 Batch 400 Loss 2.4358 Accuracy 0.5355
# Epoch 8 Batch 450 Loss 2.4319 Accuracy 0.5362
# Epoch 8 Batch 500 Loss 2.4316 Accuracy 0.5364
# Epoch 8 Batch 550 Loss 2.4265 Accuracy 0.5370
# Epoch 8 Batch 600 Loss 2.4269 Accuracy 0.5372
# Epoch 8 Batch 650 Loss 2.4243 Accuracy 0.5376
# Epoch 8 Batch 700 Loss 2.4232 Accuracy 0.5379
# Epoch 8 Batch 750 Loss 2.4215 Accuracy 0.5382
# Epoch 8 Batch 800 Loss 2.4210 Accuracy 0.5384
# Epoch 8 Loss 2.4205 Accuracy 0.5386
# Time taken for epoch 8: 93.29 secs
#
# Epoch 9 Batch 0 Loss 2.2224 Accuracy 0.5577
# Epoch 9 Batch 50 Loss 2.2363 Accuracy 0.5624
# Epoch 9 Batch 100 Loss 2.2229 Accuracy 0.5644
# Epoch 9 Batch 150 Loss 2.2206 Accuracy 0.5647
# Epoch 9 Batch 200 Loss 2.2275 Accuracy 0.5638
# Epoch 9 Batch 250 Loss 2.2313 Accuracy 0.5635
# Epoch 9 Batch 300 Loss 2.2322 Accuracy 0.5631
# Epoch 9 Batch 350 Loss 2.2351 Accuracy 0.5629
# Epoch 9 Batch 400 Loss 2.2393 Accuracy 0.5623
# Epoch 9 Batch 450 Loss 2.2402 Accuracy 0.5626
# Epoch 9 Batch 500 Loss 2.2384 Accuracy 0.5629
# Epoch 9 Batch 550 Loss 2.2365 Accuracy 0.5632
# Epoch 9 Batch 600 Loss 2.2359 Accuracy 0.5634
# Epoch 9 Batch 650 Loss 2.2363 Accuracy 0.5634
# Epoch 9 Batch 700 Loss 2.2372 Accuracy 0.5632
# Epoch 9 Batch 750 Loss 2.2382 Accuracy 0.5633
# Epoch 9 Batch 800 Loss 2.2401 Accuracy 0.5630
# Epoch 9 Loss 2.2402 Accuracy 0.5630
# Time taken for epoch 9: 92.98 secs
#
# Epoch 10 Batch 0 Loss 2.0717 Accuracy 0.5865
# Epoch 10 Batch 50 Loss 2.0804 Accuracy 0.5831
# Epoch 10 Batch 100 Loss 2.0879 Accuracy 0.5830
# Epoch 10 Batch 150 Loss 2.0929 Accuracy 0.5822
# Epoch 10 Batch 200 Loss 2.0943 Accuracy 0.5822
# Epoch 10 Batch 250 Loss 2.0946 Accuracy 0.5825
# Epoch 10 Batch 300 Loss 2.0951 Accuracy 0.5823
# Epoch 10 Batch 350 Loss 2.0964 Accuracy 0.5822
# Epoch 10 Batch 400 Loss 2.0933 Accuracy 0.5828
# Epoch 10 Batch 450 Loss 2.0938 Accuracy 0.5826
# Epoch 10 Batch 500 Loss 2.0954 Accuracy 0.5824
# Epoch 10 Batch 550 Loss 2.0968 Accuracy 0.5826
# Epoch 10 Batch 600 Loss 2.0987 Accuracy 0.5823
# Epoch 10 Batch 650 Loss 2.0979 Accuracy 0.5825
# Epoch 10 Batch 700 Loss 2.0977 Accuracy 0.5827
# Epoch 10 Batch 750 Loss 2.0979 Accuracy 0.5829
# Epoch 10 Batch 800 Loss 2.0993 Accuracy 0.5828
# Saving checkpoint for epoch 10 at ./checkpoints/train/ckpt-2
# Epoch 10 Loss 2.0995 Accuracy 0.5828
# Time taken for epoch 10: 93.78 secs
#
# Epoch 11 Batch 0 Loss 1.7833 Accuracy 0.6147
# Epoch 11 Batch 50 Loss 1.9372 Accuracy 0.6047
# Epoch 11 Batch 100 Loss 1.9593 Accuracy 0.6009
# Epoch 11 Batch 150 Loss 1.9541 Accuracy 0.6030
# Epoch 11 Batch 200 Loss 1.9633 Accuracy 0.6014
# Epoch 11 Batch 250 Loss 1.9714 Accuracy 0.6000
# Epoch 11 Batch 300 Loss 1.9729 Accuracy 0.6000
# Epoch 11 Batch 350 Loss 1.9746 Accuracy 0.5996
# Epoch 11 Batch 400 Loss 1.9771 Accuracy 0.5993
# Epoch 11 Batch 450 Loss 1.9746 Accuracy 0.5998
# Epoch 11 Batch 500 Loss 1.9780 Accuracy 0.5994
# Epoch 11 Batch 550 Loss 1.9775 Accuracy 0.5994
# Epoch 11 Batch 600 Loss 1.9809 Accuracy 0.5989
# Epoch 11 Batch 650 Loss 1.9836 Accuracy 0.5988
# Epoch 11 Batch 700 Loss 1.9835 Accuracy 0.5989
# Epoch 11 Batch 750 Loss 1.9857 Accuracy 0.5987
# Epoch 11 Batch 800 Loss 1.9867 Accuracy 0.5987
# Epoch 11 Loss 1.9880 Accuracy 0.5984
# Time taken for epoch 11: 92.91 secs
#
# Epoch 12 Batch 0 Loss 1.9531 Accuracy 0.6104
# Epoch 12 Batch 50 Loss 1.8406 Accuracy 0.6195
# Epoch 12 Batch 100 Loss 1.8547 Accuracy 0.6171
# Epoch 12 Batch 150 Loss 1.8600 Accuracy 0.6159
# Epoch 12 Batch 200 Loss 1.8636 Accuracy 0.6155
# Epoch 12 Batch 250 Loss 1.8661 Accuracy 0.6161
# Epoch 12 Batch 300 Loss 1.8686 Accuracy 0.6151
# Epoch 12 Batch 350 Loss 1.8746 Accuracy 0.6141
# Epoch 12 Batch 400 Loss 1.8750 Accuracy 0.6141
# Epoch 12 Batch 450 Loss 1.8795 Accuracy 0.6135
# Epoch 12 Batch 500 Loss 1.8792 Accuracy 0.6138
# Epoch 12 Batch 550 Loss 1.8815 Accuracy 0.6135
# Epoch 12 Batch 600 Loss 1.8837 Accuracy 0.6133
# Epoch 12 Batch 650 Loss 1.8851 Accuracy 0.6131
# Epoch 12 Batch 700 Loss 1.8886 Accuracy 0.6127
# Epoch 12 Batch 750 Loss 1.8891 Accuracy 0.6127
# Epoch 12 Batch 800 Loss 1.8911 Accuracy 0.6126
# Epoch 12 Loss 1.8918 Accuracy 0.6125
# Time taken for epoch 12: 93.75 secs
#
# Epoch 13 Batch 0 Loss 1.5699 Accuracy 0.6586
# Epoch 13 Batch 50 Loss 1.7710 Accuracy 0.6303
# Epoch 13 Batch 100 Loss 1.7724 Accuracy 0.6305
# Epoch 13 Batch 150 Loss 1.7781 Accuracy 0.6295
# Epoch 13 Batch 200 Loss 1.7863 Accuracy 0.6282
# Epoch 13 Batch 250 Loss 1.7850 Accuracy 0.6288
# Epoch 13 Batch 300 Loss 1.7829 Accuracy 0.6292
# Epoch 13 Batch 350 Loss 1.7903 Accuracy 0.6277
# Epoch 13 Batch 400 Loss 1.7906 Accuracy 0.6279
# Epoch 13 Batch 450 Loss 1.7937 Accuracy 0.6273
# Epoch 13 Batch 500 Loss 1.7975 Accuracy 0.6266
# Epoch 13 Batch 550 Loss 1.7983 Accuracy 0.6263
# Epoch 13 Batch 600 Loss 1.8001 Accuracy 0.6260
# Epoch 13 Batch 650 Loss 1.8003 Accuracy 0.6259
# Epoch 13 Batch 700 Loss 1.8039 Accuracy 0.6254
# Epoch 13 Batch 750 Loss 1.8080 Accuracy 0.6249
# Epoch 13 Batch 800 Loss 1.8119 Accuracy 0.6243
# Epoch 13 Loss 1.8118 Accuracy 0.6243
# Time taken for epoch 13: 92.79 secs
#
# Epoch 14 Batch 0 Loss 1.9068 Accuracy 0.6008
# Epoch 14 Batch 50 Loss 1.7063 Accuracy 0.6388
# Epoch 14 Batch 100 Loss 1.6971 Accuracy 0.6412
# Epoch 14 Batch 150 Loss 1.7017 Accuracy 0.6400
# Epoch 14 Batch 200 Loss 1.7067 Accuracy 0.6392
# Epoch 14 Batch 250 Loss 1.7150 Accuracy 0.6380
# Epoch 14 Batch 300 Loss 1.7181 Accuracy 0.6377
# Epoch 14 Batch 350 Loss 1.7194 Accuracy 0.6373
# Epoch 14 Batch 400 Loss 1.7203 Accuracy 0.6372
# Epoch 14 Batch 450 Loss 1.7239 Accuracy 0.6369
# Epoch 14 Batch 500 Loss 1.7256 Accuracy 0.6369
# Epoch 14 Batch 550 Loss 1.7286 Accuracy 0.6366
# Epoch 14 Batch 600 Loss 1.7321 Accuracy 0.6359
# Epoch 14 Batch 650 Loss 1.7338 Accuracy 0.6358
# Epoch 14 Batch 700 Loss 1.7361 Accuracy 0.6355
# Epoch 14 Batch 750 Loss 1.7380 Accuracy 0.6353
# Epoch 14 Batch 800 Loss 1.7395 Accuracy 0.6351
# Epoch 14 Loss 1.7405 Accuracy 0.6350
# Time taken for epoch 14: 93.09 secs
#
# Epoch 15 Batch 0 Loss 1.6335 Accuracy 0.6504
# Epoch 15 Batch 50 Loss 1.6512 Accuracy 0.6474
# Epoch 15 Batch 100 Loss 1.6439 Accuracy 0.6489
# Epoch 15 Batch 150 Loss 1.6472 Accuracy 0.6487
# Epoch 15 Batch 200 Loss 1.6470 Accuracy 0.6483
# Epoch 15 Batch 250 Loss 1.6513 Accuracy 0.6475
# Epoch 15 Batch 300 Loss 1.6569 Accuracy 0.6467
# Epoch 15 Batch 350 Loss 1.6590 Accuracy 0.6464
# Epoch 15 Batch 400 Loss 1.6611 Accuracy 0.6460
# Epoch 15 Batch 450 Loss 1.6648 Accuracy 0.6456
# Epoch 15 Batch 500 Loss 1.6688 Accuracy 0.6449
# Epoch 15 Batch 550 Loss 1.6686 Accuracy 0.6451
# Epoch 15 Batch 600 Loss 1.6709 Accuracy 0.6447
# Epoch 15 Batch 650 Loss 1.6736 Accuracy 0.6444
# Epoch 15 Batch 700 Loss 1.6756 Accuracy 0.6441
# Epoch 15 Batch 750 Loss 1.6782 Accuracy 0.6438
# Epoch 15 Batch 800 Loss 1.6804 Accuracy 0.6437
# Saving checkpoint for epoch 15 at ./checkpoints/train/ckpt-3
# Epoch 15 Loss 1.6805 Accuracy 0.6437
# Time taken for epoch 15: 93.18 secs
#
# Epoch 16 Batch 0 Loss 1.8470 Accuracy 0.6135
# Epoch 16 Batch 50 Loss 1.5964 Accuracy 0.6566
# Epoch 16 Batch 100 Loss 1.5962 Accuracy 0.6570
# Epoch 16 Batch 150 Loss 1.5977 Accuracy 0.6565
# Epoch 16 Batch 200 Loss 1.5991 Accuracy 0.6565
# Epoch 16 Batch 250 Loss 1.6043 Accuracy 0.6554
# Epoch 16 Batch 300 Loss 1.6062 Accuracy 0.6550
# Epoch 16 Batch 350 Loss 1.6049 Accuracy 0.6550
# Epoch 16 Batch 400 Loss 1.6063 Accuracy 0.6549
# Epoch 16 Batch 450 Loss 1.6104 Accuracy 0.6542
# Epoch 16 Batch 500 Loss 1.6091 Accuracy 0.6545
# Epoch 16 Batch 550 Loss 1.6093 Accuracy 0.6546
# Epoch 16 Batch 600 Loss 1.6131 Accuracy 0.6540
# Epoch 16 Batch 650 Loss 1.6169 Accuracy 0.6536
# Epoch 16 Batch 700 Loss 1.6195 Accuracy 0.6533
# Epoch 16 Batch 750 Loss 1.6206 Accuracy 0.6532
# Epoch 16 Batch 800 Loss 1.6257 Accuracy 0.6524
# Epoch 16 Loss 1.6254 Accuracy 0.6525
# Time taken for epoch 16: 93.70 secs
#
# Epoch 17 Batch 0 Loss 1.5212 Accuracy 0.6914
# Epoch 17 Batch 50 Loss 1.5188 Accuracy 0.6717
# Epoch 17 Batch 100 Loss 1.5282 Accuracy 0.6676
# Epoch 17 Batch 150 Loss 1.5338 Accuracy 0.6670
# Epoch 17 Batch 200 Loss 1.5344 Accuracy 0.6665
# Epoch 17 Batch 250 Loss 1.5407 Accuracy 0.6657
# Epoch 17 Batch 300 Loss 1.5453 Accuracy 0.6650
# Epoch 17 Batch 350 Loss 1.5476 Accuracy 0.6645
# Epoch 17 Batch 400 Loss 1.5518 Accuracy 0.6640
# Epoch 17 Batch 450 Loss 1.5564 Accuracy 0.6630
# Epoch 17 Batch 500 Loss 1.5594 Accuracy 0.6624
# Epoch 17 Batch 550 Loss 1.5614 Accuracy 0.6623
# Epoch 17 Batch 600 Loss 1.5642 Accuracy 0.6619
# Epoch 17 Batch 650 Loss 1.5675 Accuracy 0.6613
# Epoch 17 Batch 700 Loss 1.5691 Accuracy 0.6612
# Epoch 17 Batch 750 Loss 1.5727 Accuracy 0.6607
# Epoch 17 Batch 800 Loss 1.5762 Accuracy 0.6602
# Epoch 17 Loss 1.5763 Accuracy 0.6602
# Time taken for epoch 17: 92.35 secs
#
# Epoch 18 Batch 0 Loss 1.5132 Accuracy 0.6732
# Epoch 18 Batch 50 Loss 1.4607 Accuracy 0.6783
# Epoch 18 Batch 100 Loss 1.4710 Accuracy 0.6767
# Epoch 18 Batch 150 Loss 1.4795 Accuracy 0.6756
# Epoch 18 Batch 200 Loss 1.4907 Accuracy 0.6736
# Epoch 18 Batch 250 Loss 1.4935 Accuracy 0.6730
# Epoch 18 Batch 300 Loss 1.4963 Accuracy 0.6726
# Epoch 18 Batch 350 Loss 1.5040 Accuracy 0.6713
# Epoch 18 Batch 400 Loss 1.5079 Accuracy 0.6706
# Epoch 18 Batch 450 Loss 1.5100 Accuracy 0.6703
# Epoch 18 Batch 500 Loss 1.5129 Accuracy 0.6696
# Epoch 18 Batch 550 Loss 1.5158 Accuracy 0.6693
# Epoch 18 Batch 600 Loss 1.5191 Accuracy 0.6688
# Epoch 18 Batch 650 Loss 1.5219 Accuracy 0.6683
# Epoch 18 Batch 700 Loss 1.5261 Accuracy 0.6677
# Epoch 18 Batch 750 Loss 1.5296 Accuracy 0.6672
# Epoch 18 Batch 800 Loss 1.5337 Accuracy 0.6665
# Epoch 18 Loss 1.5329 Accuracy 0.6667
# Time taken for epoch 18: 92.35 secs
#
# Epoch 19 Batch 0 Loss 1.5801 Accuracy 0.6387
# Epoch 19 Batch 50 Loss 1.4525 Accuracy 0.6795
# Epoch 19 Batch 100 Loss 1.4546 Accuracy 0.6801
# Epoch 19 Batch 150 Loss 1.4527 Accuracy 0.6806
# Epoch 19 Batch 200 Loss 1.4574 Accuracy 0.6797
# Epoch 19 Batch 250 Loss 1.4644 Accuracy 0.6785
# Epoch 19 Batch 300 Loss 1.4671 Accuracy 0.6778
# Epoch 19 Batch 350 Loss 1.4699 Accuracy 0.6771
# Epoch 19 Batch 400 Loss 1.4715 Accuracy 0.6770
# Epoch 19 Batch 450 Loss 1.4737 Accuracy 0.6765
# Epoch 19 Batch 500 Loss 1.4781 Accuracy 0.6757
# Epoch 19 Batch 550 Loss 1.4797 Accuracy 0.6754
# Epoch 19 Batch 600 Loss 1.4834 Accuracy 0.6747
# Epoch 19 Batch 650 Loss 1.4862 Accuracy 0.6743
# Epoch 19 Batch 700 Loss 1.4886 Accuracy 0.6740
# Epoch 19 Batch 750 Loss 1.4900 Accuracy 0.6738
# Epoch 19 Batch 800 Loss 1.4926 Accuracy 0.6734
# Epoch 19 Loss 1.4933 Accuracy 0.6733
# Time taken for epoch 19: 92.56 secs
#
# Epoch 20 Batch 0 Loss 1.4551 Accuracy 0.6790
# Epoch 20 Batch 50 Loss 1.4161 Accuracy 0.6848
# Epoch 20 Batch 100 Loss 1.4120 Accuracy 0.6847
# Epoch 20 Batch 150 Loss 1.4147 Accuracy 0.6846
# Epoch 20 Batch 200 Loss 1.4185 Accuracy 0.6841
# Epoch 20 Batch 250 Loss 1.4257 Accuracy 0.6831
# Epoch 20 Batch 300 Loss 1.4281 Accuracy 0.6827
# Epoch 20 Batch 350 Loss 1.4321 Accuracy 0.6824
# Epoch 20 Batch 400 Loss 1.4325 Accuracy 0.6825
# Epoch 20 Batch 450 Loss 1.4362 Accuracy 0.6818
# Epoch 20 Batch 500 Loss 1.4393 Accuracy 0.6814
# Epoch 20 Batch 550 Loss 1.4411 Accuracy 0.6811
# Epoch 20 Batch 600 Loss 1.4441 Accuracy 0.6806
# Epoch 20 Batch 650 Loss 1.4460 Accuracy 0.6804
# Epoch 20 Batch 700 Loss 1.4470 Accuracy 0.6803
# Epoch 20 Batch 750 Loss 1.4520 Accuracy 0.6795
# Epoch 20 Batch 800 Loss 1.4560 Accuracy 0.6790
# Saving checkpoint for epoch 20 at ./checkpoints/train/ckpt-4
# Epoch 20 Loss 1.4570 Accuracy 0.6788
# Time taken for epoch 20: 92.98 secs
#
# Epoch 21 Batch 0 Loss 1.3851 Accuracy 0.6934
# Epoch 21 Batch 50 Loss 1.3916 Accuracy 0.6906
# Epoch 21 Batch 100 Loss 1.3802 Accuracy 0.6924
# Epoch 21 Batch 150 Loss 1.3776 Accuracy 0.6926
# Epoch 21 Batch 200 Loss 1.3817 Accuracy 0.6916
# Epoch 21 Batch 250 Loss 1.3856 Accuracy 0.6910
# Epoch 21 Batch 300 Loss 1.3899 Accuracy 0.6900
# Epoch 21 Batch 350 Loss 1.3937 Accuracy 0.6893
# Epoch 21 Batch 400 Loss 1.3977 Accuracy 0.6889
# Epoch 21 Batch 450 Loss 1.4022 Accuracy 0.6881
# Epoch 21 Batch 500 Loss 1.4052 Accuracy 0.6875
# Epoch 21 Batch 550 Loss 1.4069 Accuracy 0.6874
# Epoch 21 Batch 600 Loss 1.4102 Accuracy 0.6869
# Epoch 21 Batch 650 Loss 1.4129 Accuracy 0.6864
# Epoch 21 Batch 700 Loss 1.4176 Accuracy 0.6856
# Epoch 21 Batch 750 Loss 1.4199 Accuracy 0.6853
# Epoch 21 Batch 800 Loss 1.4228 Accuracy 0.6848
# Epoch 21 Loss 1.4229 Accuracy 0.6848
# Time taken for epoch 21: 92.40 secs
#
# Epoch 22 Batch 0 Loss 1.3779 Accuracy 0.6781
# Epoch 22 Batch 50 Loss 1.3401 Accuracy 0.6999
# Epoch 22 Batch 100 Loss 1.3458 Accuracy 0.6980
# Epoch 22 Batch 150 Loss 1.3509 Accuracy 0.6970
# Epoch 22 Batch 200 Loss 1.3527 Accuracy 0.6970
# Epoch 22 Batch 250 Loss 1.3583 Accuracy 0.6955
# Epoch 22 Batch 300 Loss 1.3637 Accuracy 0.6942
# Epoch 22 Batch 350 Loss 1.3680 Accuracy 0.6933
# Epoch 22 Batch 400 Loss 1.3681 Accuracy 0.6933
# Epoch 22 Batch 450 Loss 1.3707 Accuracy 0.6929
# Epoch 22 Batch 500 Loss 1.3747 Accuracy 0.6923
# Epoch 22 Batch 550 Loss 1.3806 Accuracy 0.6913
# Epoch 22 Batch 600 Loss 1.3820 Accuracy 0.6910
# Epoch 22 Batch 650 Loss 1.3840 Accuracy 0.6906
# Epoch 22 Batch 700 Loss 1.3860 Accuracy 0.6902
# Epoch 22 Batch 750 Loss 1.3885 Accuracy 0.6898
# Epoch 22 Batch 800 Loss 1.3907 Accuracy 0.6894
# Epoch 22 Loss 1.3917 Accuracy 0.6893
# Time taken for epoch 22: 92.95 secs
#
# Epoch 23 Batch 0 Loss 1.4039 Accuracy 0.6899
# Epoch 23 Batch 50 Loss 1.2909 Accuracy 0.7055
# Epoch 23 Batch 100 Loss 1.3028 Accuracy 0.7035
# Epoch 23 Batch 150 Loss 1.3084 Accuracy 0.7023
# Epoch 23 Batch 200 Loss 1.3163 Accuracy 0.7014
# Epoch 23 Batch 250 Loss 1.3194 Accuracy 0.7012
# Epoch 23 Batch 300 Loss 1.3252 Accuracy 0.7001
# Epoch 23 Batch 350 Loss 1.3317 Accuracy 0.6989
# Epoch 23 Batch 400 Loss 1.3354 Accuracy 0.6984
# Epoch 23 Batch 450 Loss 1.3375 Accuracy 0.6979
# Epoch 23 Batch 500 Loss 1.3441 Accuracy 0.6966
# Epoch 23 Batch 550 Loss 1.3465 Accuracy 0.6964
# Epoch 23 Batch 600 Loss 1.3502 Accuracy 0.6958
# Epoch 23 Batch 650 Loss 1.3555 Accuracy 0.6948
# Epoch 23 Batch 700 Loss 1.3597 Accuracy 0.6939
# Epoch 23 Batch 750 Loss 1.3626 Accuracy 0.6935
# Epoch 23 Batch 800 Loss 1.3645 Accuracy 0.6932
# Epoch 23 Loss 1.3646 Accuracy 0.6932
# Time taken for epoch 23: 93.43 secs
#
# Epoch 24 Batch 0 Loss 1.3702 Accuracy 0.6913
# Epoch 24 Batch 50 Loss 1.2918 Accuracy 0.7080
# Epoch 24 Batch 100 Loss 1.2876 Accuracy 0.7080
# Epoch 24 Batch 150 Loss 1.2849 Accuracy 0.7078
# Epoch 24 Batch 200 Loss 1.2939 Accuracy 0.7056
# Epoch 24 Batch 250 Loss 1.2982 Accuracy 0.7049
# Epoch 24 Batch 300 Loss 1.3033 Accuracy 0.7038
# Epoch 24 Batch 350 Loss 1.3091 Accuracy 0.7028
# Epoch 24 Batch 400 Loss 1.3135 Accuracy 0.7020
# Epoch 24 Batch 450 Loss 1.3141 Accuracy 0.7020
# Epoch 24 Batch 500 Loss 1.3173 Accuracy 0.7013
# Epoch 24 Batch 550 Loss 1.3210 Accuracy 0.7007
# Epoch 24 Batch 600 Loss 1.3258 Accuracy 0.6999
# Epoch 24 Batch 650 Loss 1.3276 Accuracy 0.6995
# Epoch 24 Batch 700 Loss 1.3299 Accuracy 0.6990
# Epoch 24 Batch 750 Loss 1.3335 Accuracy 0.6984
# Epoch 24 Batch 800 Loss 1.3373 Accuracy 0.6978
# Epoch 24 Loss 1.3372 Accuracy 0.6978
# Time taken for epoch 24: 93.02 secs
#
# Epoch 25 Batch 0 Loss 1.2178 Accuracy 0.7193
# Epoch 25 Batch 50 Loss 1.2639 Accuracy 0.7093
# Epoch 25 Batch 100 Loss 1.2696 Accuracy 0.7084
# Epoch 25 Batch 150 Loss 1.2677 Accuracy 0.7094
# Epoch 25 Batch 200 Loss 1.2708 Accuracy 0.7092
# Epoch 25 Batch 250 Loss 1.2770 Accuracy 0.7082
# Epoch 25 Batch 300 Loss 1.2805 Accuracy 0.7076
# Epoch 25 Batch 350 Loss 1.2854 Accuracy 0.7067
# Epoch 25 Batch 400 Loss 1.2869 Accuracy 0.7064
# Epoch 25 Batch 450 Loss 1.2912 Accuracy 0.7055
# Epoch 25 Batch 500 Loss 1.2932 Accuracy 0.7053
# Epoch 25 Batch 550 Loss 1.2972 Accuracy 0.7045
# Epoch 25 Batch 600 Loss 1.2999 Accuracy 0.7040
# Epoch 25 Batch 650 Loss 1.3020 Accuracy 0.7035
# Epoch 25 Batch 700 Loss 1.3066 Accuracy 0.7028
# Epoch 25 Batch 750 Loss 1.3093 Accuracy 0.7025
# Epoch 25 Batch 800 Loss 1.3125 Accuracy 0.7020
# Saving checkpoint for epoch 25 at ./checkpoints/train/ckpt-5
# Epoch 25 Loss 1.3128 Accuracy 0.7019
# Time taken for epoch 25: 93.60 secs
#
# Epoch 26 Batch 0 Loss 1.3147 Accuracy 0.6934
# Epoch 26 Batch 50 Loss 1.2430 Accuracy 0.7141
# Epoch 26 Batch 100 Loss 1.2442 Accuracy 0.7140
# Epoch 26 Batch 150 Loss 1.2458 Accuracy 0.7136
# Epoch 26 Batch 200 Loss 1.2539 Accuracy 0.7114
# Epoch 26 Batch 250 Loss 1.2574 Accuracy 0.7112
# Epoch 26 Batch 300 Loss 1.2617 Accuracy 0.7104
# Epoch 26 Batch 350 Loss 1.2640 Accuracy 0.7103
# Epoch 26 Batch 400 Loss 1.2653 Accuracy 0.7099
# Epoch 26 Batch 450 Loss 1.2675 Accuracy 0.7098
# Epoch 26 Batch 500 Loss 1.2700 Accuracy 0.7093
# Epoch 26 Batch 550 Loss 1.2721 Accuracy 0.7088
# Epoch 26 Batch 600 Loss 1.2774 Accuracy 0.7080
# Epoch 26 Batch 650 Loss 1.2795 Accuracy 0.7076
# Epoch 26 Batch 700 Loss 1.2822 Accuracy 0.7071
# Epoch 26 Batch 750 Loss 1.2855 Accuracy 0.7064
# Epoch 26 Batch 800 Loss 1.2885 Accuracy 0.7059
# Epoch 26 Loss 1.2892 Accuracy 0.7057
# Time taken for epoch 26: 92.90 secs
#
# Epoch 27 Batch 0 Loss 1.3897 Accuracy 0.6920
# Epoch 27 Batch 50 Loss 1.2145 Accuracy 0.7173
# Epoch 27 Batch 100 Loss 1.2242 Accuracy 0.7158
# Epoch 27 Batch 150 Loss 1.2284 Accuracy 0.7154
# Epoch 27 Batch 200 Loss 1.2331 Accuracy 0.7148
# Epoch 27 Batch 250 Loss 1.2356 Accuracy 0.7145
# Epoch 27 Batch 300 Loss 1.2389 Accuracy 0.7143
# Epoch 27 Batch 350 Loss 1.2427 Accuracy 0.7137
# Epoch 27 Batch 400 Loss 1.2425 Accuracy 0.7139
# Epoch 27 Batch 450 Loss 1.2438 Accuracy 0.7135
# Epoch 27 Batch 500 Loss 1.2472 Accuracy 0.7130
# Epoch 27 Batch 550 Loss 1.2496 Accuracy 0.7126
# Epoch 27 Batch 600 Loss 1.2518 Accuracy 0.7122
# Epoch 27 Batch 650 Loss 1.2568 Accuracy 0.7111
# Epoch 27 Batch 700 Loss 1.2594 Accuracy 0.7106
# Epoch 27 Batch 750 Loss 1.2629 Accuracy 0.7101
# Epoch 27 Batch 800 Loss 1.2677 Accuracy 0.7093
# Epoch 27 Loss 1.2675 Accuracy 0.7094
# Time taken for epoch 27: 92.36 secs
#
# Epoch 28 Batch 0 Loss 1.2528 Accuracy 0.7223
# Epoch 28 Batch 50 Loss 1.2040 Accuracy 0.7195
# Epoch 28 Batch 100 Loss 1.2003 Accuracy 0.7197
# Epoch 28 Batch 150 Loss 1.2069 Accuracy 0.7191
# Epoch 28 Batch 200 Loss 1.2067 Accuracy 0.7188
# Epoch 28 Batch 250 Loss 1.2126 Accuracy 0.7178
# Epoch 28 Batch 300 Loss 1.2160 Accuracy 0.7170
# Epoch 28 Batch 350 Loss 1.2195 Accuracy 0.7165
# Epoch 28 Batch 400 Loss 1.2194 Accuracy 0.7167
# Epoch 28 Batch 450 Loss 1.2227 Accuracy 0.7164
# Epoch 28 Batch 500 Loss 1.2270 Accuracy 0.7155
# Epoch 28 Batch 550 Loss 1.2287 Accuracy 0.7153
# Epoch 28 Batch 600 Loss 1.2330 Accuracy 0.7146
# Epoch 28 Batch 650 Loss 1.2374 Accuracy 0.7137
# Epoch 28 Batch 700 Loss 1.2395 Accuracy 0.7133
# Epoch 28 Batch 750 Loss 1.2439 Accuracy 0.7127
# Epoch 28 Batch 800 Loss 1.2470 Accuracy 0.7123
# Epoch 28 Loss 1.2484 Accuracy 0.7120
# Time taken for epoch 28: 92.98 secs
#
# Epoch 29 Batch 0 Loss 1.2913 Accuracy 0.6988
# Epoch 29 Batch 50 Loss 1.1783 Accuracy 0.7249
# Epoch 29 Batch 100 Loss 1.1772 Accuracy 0.7254
# Epoch 29 Batch 150 Loss 1.1881 Accuracy 0.7229
# Epoch 29 Batch 200 Loss 1.1922 Accuracy 0.7212
# Epoch 29 Batch 250 Loss 1.1971 Accuracy 0.7207
# Epoch 29 Batch 300 Loss 1.2005 Accuracy 0.7203
# Epoch 29 Batch 350 Loss 1.2026 Accuracy 0.7201
# Epoch 29 Batch 400 Loss 1.2032 Accuracy 0.7200
# Epoch 29 Batch 450 Loss 1.2064 Accuracy 0.7193
# Epoch 29 Batch 500 Loss 1.2091 Accuracy 0.7189
# Epoch 29 Batch 550 Loss 1.2108 Accuracy 0.7186
# Epoch 29 Batch 600 Loss 1.2138 Accuracy 0.7182
# Epoch 29 Batch 650 Loss 1.2170 Accuracy 0.7177
# Epoch 29 Batch 700 Loss 1.2210 Accuracy 0.7170
# Epoch 29 Batch 750 Loss 1.2237 Accuracy 0.7165
# Epoch 29 Batch 800 Loss 1.2265 Accuracy 0.7161
# Epoch 29 Loss 1.2265 Accuracy 0.7161
# Time taken for epoch 29: 92.64 secs
#
# Epoch 30 Batch 0 Loss 1.2578 Accuracy 0.7112
# Epoch 30 Batch 50 Loss 1.1724 Accuracy 0.7268
# Epoch 30 Batch 100 Loss 1.1697 Accuracy 0.7271
# Epoch 30 Batch 150 Loss 1.1672 Accuracy 0.7273
# Epoch 30 Batch 200 Loss 1.1736 Accuracy 0.7263
# Epoch 30 Batch 250 Loss 1.1771 Accuracy 0.7254
# Epoch 30 Batch 300 Loss 1.1789 Accuracy 0.7250
# Epoch 30 Batch 350 Loss 1.1837 Accuracy 0.7241
# Epoch 30 Batch 400 Loss 1.1883 Accuracy 0.7233
# Epoch 30 Batch 450 Loss 1.1927 Accuracy 0.7226
# Epoch 30 Batch 500 Loss 1.1929 Accuracy 0.7226
# Epoch 30 Batch 550 Loss 1.1946 Accuracy 0.7224
# Epoch 30 Batch 600 Loss 1.1969 Accuracy 0.7221
# Epoch 30 Batch 650 Loss 1.1993 Accuracy 0.7215
# Epoch 30 Batch 700 Loss 1.2044 Accuracy 0.7206
# Epoch 30 Batch 750 Loss 1.2064 Accuracy 0.7203
# Epoch 30 Batch 800 Loss 1.2092 Accuracy 0.7197
# Saving checkpoint for epoch 30 at ./checkpoints/train/ckpt-6
# Epoch 30 Loss 1.2102 Accuracy 0.7195
# Time taken for epoch 30: 93.36 secs
#
# Epoch 31 Batch 0 Loss 1.0559 Accuracy 0.7435
# Epoch 31 Batch 50 Loss 1.1503 Accuracy 0.7297
# Epoch 31 Batch 100 Loss 1.1434 Accuracy 0.7307
# Epoch 31 Batch 150 Loss 1.1432 Accuracy 0.7308
# Epoch 31 Batch 200 Loss 1.1514 Accuracy 0.7291
# Epoch 31 Batch 250 Loss 1.1547 Accuracy 0.7284
# Epoch 31 Batch 300 Loss 1.1588 Accuracy 0.7275
# Epoch 31 Batch 350 Loss 1.1665 Accuracy 0.7259
# Epoch 31 Batch 400 Loss 1.1687 Accuracy 0.7255
# Epoch 31 Batch 450 Loss 1.1738 Accuracy 0.7247
# Epoch 31 Batch 500 Loss 1.1749 Accuracy 0.7245
# Epoch 31 Batch 550 Loss 1.1783 Accuracy 0.7240
# Epoch 31 Batch 600 Loss 1.1808 Accuracy 0.7237
# Epoch 31 Batch 650 Loss 1.1834 Accuracy 0.7232
# Epoch 31 Batch 700 Loss 1.1865 Accuracy 0.7226
# Epoch 31 Batch 750 Loss 1.1886 Accuracy 0.7223
# Epoch 31 Batch 800 Loss 1.1912 Accuracy 0.7219
# Epoch 31 Loss 1.1919 Accuracy 0.7218
# Time taken for epoch 31: 92.27 secs
#
# Epoch 32 Batch 0 Loss 1.0171 Accuracy 0.7420
# Epoch 32 Batch 50 Loss 1.1340 Accuracy 0.7327
# Epoch 32 Batch 100 Loss 1.1298 Accuracy 0.7333
# Epoch 32 Batch 150 Loss 1.1333 Accuracy 0.7328
# Epoch 32 Batch 200 Loss 1.1363 Accuracy 0.7317
# Epoch 32 Batch 250 Loss 1.1435 Accuracy 0.7307
# Epoch 32 Batch 300 Loss 1.1427 Accuracy 0.7306
# Epoch 32 Batch 350 Loss 1.1493 Accuracy 0.7292
# Epoch 32 Batch 400 Loss 1.1510 Accuracy 0.7288
# Epoch 32 Batch 450 Loss 1.1554 Accuracy 0.7279
# Epoch 32 Batch 500 Loss 1.1582 Accuracy 0.7272
# Epoch 32 Batch 550 Loss 1.1594 Accuracy 0.7270
# Epoch 32 Batch 600 Loss 1.1616 Accuracy 0.7268
# Epoch 32 Batch 650 Loss 1.1638 Accuracy 0.7265
# Epoch 32 Batch 700 Loss 1.1671 Accuracy 0.7258
# Epoch 32 Batch 750 Loss 1.1701 Accuracy 0.7253
# Epoch 32 Batch 800 Loss 1.1742 Accuracy 0.7247
# Epoch 32 Loss 1.1743 Accuracy 0.7246
# Time taken for epoch 32: 92.21 secs
#
# Epoch 33 Batch 0 Loss 1.2247 Accuracy 0.7323
# Epoch 33 Batch 50 Loss 1.1088 Accuracy 0.7378
# Epoch 33 Batch 100 Loss 1.1143 Accuracy 0.7362
# Epoch 33 Batch 150 Loss 1.1194 Accuracy 0.7352
# Epoch 33 Batch 200 Loss 1.1237 Accuracy 0.7348
# Epoch 33 Batch 250 Loss 1.1306 Accuracy 0.7330
# Epoch 33 Batch 300 Loss 1.1365 Accuracy 0.7318
# Epoch 33 Batch 350 Loss 1.1396 Accuracy 0.7311
# Epoch 33 Batch 400 Loss 1.1421 Accuracy 0.7304
# Epoch 33 Batch 450 Loss 1.1432 Accuracy 0.7303
# Epoch 33 Batch 500 Loss 1.1442 Accuracy 0.7303
# Epoch 33 Batch 550 Loss 1.1471 Accuracy 0.7297
# Epoch 33 Batch 600 Loss 1.1512 Accuracy 0.7289
# Epoch 33 Batch 650 Loss 1.1539 Accuracy 0.7284
# Epoch 33 Batch 700 Loss 1.1577 Accuracy 0.7278
# Epoch 33 Batch 750 Loss 1.1602 Accuracy 0.7273
# Epoch 33 Batch 800 Loss 1.1617 Accuracy 0.7271
# Epoch 33 Loss 1.1618 Accuracy 0.7271
# Time taken for epoch 33: 91.95 secs
#
# Epoch 34 Batch 0 Loss 1.1283 Accuracy 0.7339
# Epoch 34 Batch 50 Loss 1.0924 Accuracy 0.7406
# Epoch 34 Batch 100 Loss 1.0912 Accuracy 0.7412
# Epoch 34 Batch 150 Loss 1.0962 Accuracy 0.7400
# Epoch 34 Batch 200 Loss 1.1065 Accuracy 0.7377
# Epoch 34 Batch 250 Loss 1.1114 Accuracy 0.7364
# Epoch 34 Batch 300 Loss 1.1155 Accuracy 0.7355
# Epoch 34 Batch 350 Loss 1.1214 Accuracy 0.7344
# Epoch 34 Batch 400 Loss 1.1267 Accuracy 0.7332
# Epoch 34 Batch 450 Loss 1.1296 Accuracy 0.7325
# Epoch 34 Batch 500 Loss 1.1319 Accuracy 0.7321
# Epoch 34 Batch 550 Loss 1.1336 Accuracy 0.7318
# Epoch 34 Batch 600 Loss 1.1353 Accuracy 0.7314
# Epoch 34 Batch 650 Loss 1.1377 Accuracy 0.7310
# Epoch 34 Batch 700 Loss 1.1406 Accuracy 0.7304
# Epoch 34 Batch 750 Loss 1.1426 Accuracy 0.7301
# Epoch 34 Batch 800 Loss 1.1461 Accuracy 0.7295
# Epoch 34 Loss 1.1471 Accuracy 0.7294
# Time taken for epoch 34: 91.66 secs
#
# Epoch 35 Batch 0 Loss 1.0314 Accuracy 0.7453
# Epoch 35 Batch 50 Loss 1.0832 Accuracy 0.7420
# Epoch 35 Batch 100 Loss 1.0920 Accuracy 0.7394
# Epoch 35 Batch 150 Loss 1.0918 Accuracy 0.7392
# Epoch 35 Batch 200 Loss 1.0950 Accuracy 0.7388
# Epoch 35 Batch 250 Loss 1.0962 Accuracy 0.7386
# Epoch 35 Batch 300 Loss 1.1026 Accuracy 0.7372
# Epoch 35 Batch 350 Loss 1.1053 Accuracy 0.7369
# Epoch 35 Batch 400 Loss 1.1073 Accuracy 0.7367
# Epoch 35 Batch 450 Loss 1.1086 Accuracy 0.7366
# Epoch 35 Batch 500 Loss 1.1113 Accuracy 0.7359
# Epoch 35 Batch 550 Loss 1.1146 Accuracy 0.7352
# Epoch 35 Batch 600 Loss 1.1184 Accuracy 0.7345
# Epoch 35 Batch 650 Loss 1.1218 Accuracy 0.7338
# Epoch 35 Batch 700 Loss 1.1235 Accuracy 0.7336
# Epoch 35 Batch 750 Loss 1.1274 Accuracy 0.7328
# Epoch 35 Batch 800 Loss 1.1313 Accuracy 0.7321
# Saving checkpoint for epoch 35 at ./checkpoints/train/ckpt-7
# Epoch 35 Loss 1.1312 Accuracy 0.7321
# Time taken for epoch 35: 93.26 secs
#
# Epoch 36 Batch 0 Loss 1.0078 Accuracy 0.7648
# Epoch 36 Batch 50 Loss 1.0788 Accuracy 0.7404
# Epoch 36 Batch 100 Loss 1.0719 Accuracy 0.7423
# Epoch 36 Batch 150 Loss 1.0732 Accuracy 0.7416
# Epoch 36 Batch 200 Loss 1.0771 Accuracy 0.7415
# Epoch 36 Batch 250 Loss 1.0829 Accuracy 0.7405
# Epoch 36 Batch 300 Loss 1.0869 Accuracy 0.7400
# Epoch 36 Batch 350 Loss 1.0915 Accuracy 0.7393
# Epoch 36 Batch 400 Loss 1.0955 Accuracy 0.7385
# Epoch 36 Batch 450 Loss 1.0987 Accuracy 0.7379
# Epoch 36 Batch 500 Loss 1.0994 Accuracy 0.7379
# Epoch 36 Batch 550 Loss 1.1018 Accuracy 0.7376
# Epoch 36 Batch 600 Loss 1.1052 Accuracy 0.7369
# Epoch 36 Batch 650 Loss 1.1077 Accuracy 0.7365
# Epoch 36 Batch 700 Loss 1.1105 Accuracy 0.7359
# Epoch 36 Batch 750 Loss 1.1153 Accuracy 0.7351
# Epoch 36 Batch 800 Loss 1.1180 Accuracy 0.7345
# Epoch 36 Loss 1.1186 Accuracy 0.7344
# Time taken for epoch 36: 93.27 secs
#
# Epoch 37 Batch 0 Loss 1.0279 Accuracy 0.7578
# Epoch 37 Batch 50 Loss 1.0395 Accuracy 0.7489
# Epoch 37 Batch 100 Loss 1.0547 Accuracy 0.7460
# Epoch 37 Batch 150 Loss 1.0627 Accuracy 0.7444
# Epoch 37 Batch 200 Loss 1.0679 Accuracy 0.7438
# Epoch 37 Batch 250 Loss 1.0753 Accuracy 0.7423
# Epoch 37 Batch 300 Loss 1.0768 Accuracy 0.7420
# Epoch 37 Batch 350 Loss 1.0797 Accuracy 0.7417
# Epoch 37 Batch 400 Loss 1.0833 Accuracy 0.7409
# Epoch 37 Batch 450 Loss 1.0854 Accuracy 0.7404
# Epoch 37 Batch 500 Loss 1.0887 Accuracy 0.7398
# Epoch 37 Batch 550 Loss 1.0925 Accuracy 0.7392
# Epoch 37 Batch 600 Loss 1.0939 Accuracy 0.7388
# Epoch 37 Batch 650 Loss 1.0970 Accuracy 0.7380
# Epoch 37 Batch 700 Loss 1.0985 Accuracy 0.7378
# Epoch 37 Batch 750 Loss 1.1017 Accuracy 0.7373
# Epoch 37 Batch 800 Loss 1.1033 Accuracy 0.7371
# Epoch 37 Loss 1.1036 Accuracy 0.7370
# Time taken for epoch 37: 92.91 secs
#
# Epoch 38 Batch 0 Loss 0.9451 Accuracy 0.7682
# Epoch 38 Batch 50 Loss 1.0466 Accuracy 0.7470
# Epoch 38 Batch 100 Loss 1.0499 Accuracy 0.7470
# Epoch 38 Batch 150 Loss 1.0462 Accuracy 0.7475
# Epoch 38 Batch 200 Loss 1.0477 Accuracy 0.7474
# Epoch 38 Batch 250 Loss 1.0546 Accuracy 0.7460
# Epoch 38 Batch 300 Loss 1.0557 Accuracy 0.7458
# Epoch 38 Batch 350 Loss 1.0592 Accuracy 0.7449
# Epoch 38 Batch 400 Loss 1.0648 Accuracy 0.7439
# Epoch 38 Batch 450 Loss 1.0679 Accuracy 0.7432
# Epoch 38 Batch 500 Loss 1.0725 Accuracy 0.7426
# Epoch 38 Batch 550 Loss 1.0773 Accuracy 0.7415
# Epoch 38 Batch 600 Loss 1.0807 Accuracy 0.7408
# Epoch 38 Batch 650 Loss 1.0852 Accuracy 0.7400
# Epoch 38 Batch 700 Loss 1.0893 Accuracy 0.7393
# Epoch 38 Batch 750 Loss 1.0921 Accuracy 0.7388
# Epoch 38 Batch 800 Loss 1.0938 Accuracy 0.7386
# Epoch 38 Loss 1.0943 Accuracy 0.7385
# Time taken for epoch 38: 92.59 secs
#
# Epoch 39 Batch 0 Loss 1.0513 Accuracy 0.7487
# Epoch 39 Batch 50 Loss 1.0379 Accuracy 0.7476
# Epoch 39 Batch 100 Loss 1.0424 Accuracy 0.7473
# Epoch 39 Batch 150 Loss 1.0393 Accuracy 0.7484
# Epoch 39 Batch 200 Loss 1.0413 Accuracy 0.7483
# Epoch 39 Batch 250 Loss 1.0484 Accuracy 0.7470
# Epoch 39 Batch 300 Loss 1.0507 Accuracy 0.7463
# Epoch 39 Batch 350 Loss 1.0540 Accuracy 0.7457
# Epoch 39 Batch 400 Loss 1.0556 Accuracy 0.7457
# Epoch 39 Batch 450 Loss 1.0590 Accuracy 0.7450
# Epoch 39 Batch 500 Loss 1.0617 Accuracy 0.7445
# Epoch 39 Batch 550 Loss 1.0662 Accuracy 0.7436
# Epoch 39 Batch 600 Loss 1.0675 Accuracy 0.7436
# Epoch 39 Batch 650 Loss 1.0703 Accuracy 0.7431
# Epoch 39 Batch 700 Loss 1.0737 Accuracy 0.7425
# Epoch 39 Batch 750 Loss 1.0759 Accuracy 0.7420
# Epoch 39 Batch 800 Loss 1.0800 Accuracy 0.7412
# Epoch 39 Loss 1.0811 Accuracy 0.7409
# Time taken for epoch 39: 92.44 secs
#
# Epoch 40 Batch 0 Loss 1.0352 Accuracy 0.7599
# Epoch 40 Batch 50 Loss 1.0251 Accuracy 0.7508
# Epoch 40 Batch 100 Loss 1.0223 Accuracy 0.7521
# Epoch 40 Batch 150 Loss 1.0261 Accuracy 0.7515
# Epoch 40 Batch 200 Loss 1.0291 Accuracy 0.7511
# Epoch 40 Batch 250 Loss 1.0306 Accuracy 0.7506
# Epoch 40 Batch 300 Loss 1.0351 Accuracy 0.7495
# Epoch 40 Batch 350 Loss 1.0402 Accuracy 0.7483
# Epoch 40 Batch 400 Loss 1.0453 Accuracy 0.7472
# Epoch 40 Batch 450 Loss 1.0459 Accuracy 0.7471
# Epoch 40 Batch 500 Loss 1.0510 Accuracy 0.7461
# Epoch 40 Batch 550 Loss 1.0554 Accuracy 0.7452
# Epoch 40 Batch 600 Loss 1.0586 Accuracy 0.7447
# Epoch 40 Batch 650 Loss 1.0619 Accuracy 0.7441
# Epoch 40 Batch 700 Loss 1.0636 Accuracy 0.7437
# Epoch 40 Batch 750 Loss 1.0676 Accuracy 0.7430
# Epoch 40 Batch 800 Loss 1.0701 Accuracy 0.7426
# Saving checkpoint for epoch 40 at ./checkpoints/train/ckpt-8
# Epoch 40 Loss 1.0706 Accuracy 0.7426
# Time taken for epoch 40: 93.31 secs
#
# Epoch 41 Batch 0 Loss 0.9508 Accuracy 0.7675
# Epoch 41 Batch 50 Loss 1.0076 Accuracy 0.7545
# Epoch 41 Batch 100 Loss 1.0047 Accuracy 0.7554
# Epoch 41 Batch 150 Loss 1.0108 Accuracy 0.7537
# Epoch 41 Batch 200 Loss 1.0183 Accuracy 0.7522
# Epoch 41 Batch 250 Loss 1.0196 Accuracy 0.7520
# Epoch 41 Batch 300 Loss 1.0264 Accuracy 0.7507
# Epoch 41 Batch 350 Loss 1.0293 Accuracy 0.7502
# Epoch 41 Batch 400 Loss 1.0311 Accuracy 0.7497
# Epoch 41 Batch 450 Loss 1.0340 Accuracy 0.7493
# Epoch 41 Batch 500 Loss 1.0387 Accuracy 0.7484
# Epoch 41 Batch 550 Loss 1.0414 Accuracy 0.7477
# Epoch 41 Batch 600 Loss 1.0446 Accuracy 0.7473
# Epoch 41 Batch 650 Loss 1.0482 Accuracy 0.7466
# Epoch 41 Batch 700 Loss 1.0518 Accuracy 0.7460
# Epoch 41 Batch 750 Loss 1.0570 Accuracy 0.7450
# Epoch 41 Batch 800 Loss 1.0597 Accuracy 0.7446
# Epoch 41 Loss 1.0603 Accuracy 0.7444
# Time taken for epoch 41: 92.09 secs
#
# Epoch 42 Batch 0 Loss 0.9455 Accuracy 0.7751
# Epoch 42 Batch 50 Loss 0.9931 Accuracy 0.7579
# Epoch 42 Batch 100 Loss 1.0067 Accuracy 0.7554
# Epoch 42 Batch 150 Loss 1.0058 Accuracy 0.7556
# Epoch 42 Batch 200 Loss 1.0125 Accuracy 0.7542
# Epoch 42 Batch 250 Loss 1.0176 Accuracy 0.7535
# Epoch 42 Batch 300 Loss 1.0216 Accuracy 0.7523
# Epoch 42 Batch 350 Loss 1.0248 Accuracy 0.7513
# Epoch 42 Batch 400 Loss 1.0276 Accuracy 0.7503
# Epoch 42 Batch 450 Loss 1.0310 Accuracy 0.7496
# Epoch 42 Batch 500 Loss 1.0339 Accuracy 0.7493
# Epoch 42 Batch 550 Loss 1.0336 Accuracy 0.7494
# Epoch 42 Batch 600 Loss 1.0370 Accuracy 0.7487
# Epoch 42 Batch 650 Loss 1.0390 Accuracy 0.7484
# Epoch 42 Batch 700 Loss 1.0433 Accuracy 0.7476
# Epoch 42 Batch 750 Loss 1.0466 Accuracy 0.7469
# Epoch 42 Batch 800 Loss 1.0505 Accuracy 0.7462
# Epoch 42 Loss 1.0504 Accuracy 0.7463
# Time taken for epoch 42: 92.68 secs
#
# Epoch 43 Batch 0 Loss 0.9907 Accuracy 0.7510
# Epoch 43 Batch 50 Loss 0.9907 Accuracy 0.7563
# Epoch 43 Batch 100 Loss 0.9837 Accuracy 0.7594
# Epoch 43 Batch 150 Loss 0.9959 Accuracy 0.7565
# Epoch 43 Batch 200 Loss 0.9949 Accuracy 0.7564
# Epoch 43 Batch 250 Loss 1.0002 Accuracy 0.7551
# Epoch 43 Batch 300 Loss 1.0041 Accuracy 0.7547
# Epoch 43 Batch 350 Loss 1.0091 Accuracy 0.7537
# Epoch 43 Batch 400 Loss 1.0162 Accuracy 0.7522
# Epoch 43 Batch 450 Loss 1.0184 Accuracy 0.7518
# Epoch 43 Batch 500 Loss 1.0200 Accuracy 0.7516
# Epoch 43 Batch 550 Loss 1.0212 Accuracy 0.7514
# Epoch 43 Batch 600 Loss 1.0250 Accuracy 0.7506
# Epoch 43 Batch 650 Loss 1.0297 Accuracy 0.7497
# Epoch 43 Batch 700 Loss 1.0326 Accuracy 0.7492
# Epoch 43 Batch 750 Loss 1.0353 Accuracy 0.7486
# Epoch 43 Batch 800 Loss 1.0384 Accuracy 0.7481
# Epoch 43 Loss 1.0388 Accuracy 0.7480
# Time taken for epoch 43: 92.06 secs
#
# Epoch 44 Batch 0 Loss 1.0614 Accuracy 0.7278
# Epoch 44 Batch 50 Loss 0.9837 Accuracy 0.7601
# Epoch 44 Batch 100 Loss 0.9846 Accuracy 0.7591
# Epoch 44 Batch 150 Loss 0.9886 Accuracy 0.7581
# Epoch 44 Batch 200 Loss 0.9938 Accuracy 0.7571
# Epoch 44 Batch 250 Loss 0.9976 Accuracy 0.7564
# Epoch 44 Batch 300 Loss 0.9994 Accuracy 0.7560
# Epoch 44 Batch 350 Loss 0.9990 Accuracy 0.7559
# Epoch 44 Batch 400 Loss 1.0027 Accuracy 0.7552
# Epoch 44 Batch 450 Loss 1.0074 Accuracy 0.7541
# Epoch 44 Batch 500 Loss 1.0091 Accuracy 0.7537
# Epoch 44 Batch 550 Loss 1.0118 Accuracy 0.7531
# Epoch 44 Batch 600 Loss 1.0138 Accuracy 0.7529
# Epoch 44 Batch 650 Loss 1.0168 Accuracy 0.7523
# Epoch 44 Batch 700 Loss 1.0207 Accuracy 0.7515
# Epoch 44 Batch 750 Loss 1.0244 Accuracy 0.7510
# Epoch 44 Batch 800 Loss 1.0272 Accuracy 0.7503
# Epoch 44 Loss 1.0274 Accuracy 0.7503
# Time taken for epoch 44: 92.13 secs
#
# Epoch 45 Batch 0 Loss 1.0651 Accuracy 0.7395
# Epoch 45 Batch 50 Loss 0.9799 Accuracy 0.7596
# Epoch 45 Batch 100 Loss 0.9742 Accuracy 0.7607
# Epoch 45 Batch 150 Loss 0.9823 Accuracy 0.7588
# Epoch 45 Batch 200 Loss 0.9854 Accuracy 0.7581
# Epoch 45 Batch 250 Loss 0.9878 Accuracy 0.7578
# Epoch 45 Batch 300 Loss 0.9881 Accuracy 0.7576
# Epoch 45 Batch 350 Loss 0.9947 Accuracy 0.7567
# Epoch 45 Batch 400 Loss 0.9949 Accuracy 0.7566
# Epoch 45 Batch 450 Loss 0.9977 Accuracy 0.7561
# Epoch 45 Batch 500 Loss 1.0011 Accuracy 0.7553
# Epoch 45 Batch 550 Loss 1.0037 Accuracy 0.7548
# Epoch 45 Batch 600 Loss 1.0051 Accuracy 0.7546
# Epoch 45 Batch 650 Loss 1.0091 Accuracy 0.7538
# Epoch 45 Batch 700 Loss 1.0125 Accuracy 0.7532
# Epoch 45 Batch 750 Loss 1.0161 Accuracy 0.7524
# Epoch 45 Batch 800 Loss 1.0192 Accuracy 0.7518
# Saving checkpoint for epoch 45 at ./checkpoints/train/ckpt-9
# Epoch 45 Loss 1.0200 Accuracy 0.7517
# Time taken for epoch 45: 92.59 secs
#
# Epoch 46 Batch 0 Loss 0.9505 Accuracy 0.7424
# Epoch 46 Batch 50 Loss 0.9728 Accuracy 0.7624
# Epoch 46 Batch 100 Loss 0.9735 Accuracy 0.7612
# Epoch 46 Batch 150 Loss 0.9733 Accuracy 0.7616
# Epoch 46 Batch 200 Loss 0.9744 Accuracy 0.7610
# Epoch 46 Batch 250 Loss 0.9797 Accuracy 0.7598
# Epoch 46 Batch 300 Loss 0.9814 Accuracy 0.7592
# Epoch 46 Batch 350 Loss 0.9841 Accuracy 0.7586
# Epoch 46 Batch 400 Loss 0.9886 Accuracy 0.7574
# Epoch 46 Batch 450 Loss 0.9910 Accuracy 0.7568
# Epoch 46 Batch 500 Loss 0.9924 Accuracy 0.7566
# Epoch 46 Batch 550 Loss 0.9955 Accuracy 0.7562
# Epoch 46 Batch 600 Loss 0.9973 Accuracy 0.7559
# Epoch 46 Batch 650 Loss 1.0020 Accuracy 0.7550
# Epoch 46 Batch 700 Loss 1.0048 Accuracy 0.7542
# Epoch 46 Batch 750 Loss 1.0072 Accuracy 0.7539
# Epoch 46 Batch 800 Loss 1.0096 Accuracy 0.7533
# Epoch 46 Loss 1.0096 Accuracy 0.7534
# Time taken for epoch 46: 91.84 secs
#
# Epoch 47 Batch 0 Loss 0.9430 Accuracy 0.7617
# Epoch 47 Batch 50 Loss 0.9637 Accuracy 0.7615
# Epoch 47 Batch 100 Loss 0.9589 Accuracy 0.7633
# Epoch 47 Batch 150 Loss 0.9684 Accuracy 0.7613
# Epoch 47 Batch 200 Loss 0.9713 Accuracy 0.7606
# Epoch 47 Batch 250 Loss 0.9756 Accuracy 0.7595
# Epoch 47 Batch 300 Loss 0.9767 Accuracy 0.7597
# Epoch 47 Batch 350 Loss 0.9795 Accuracy 0.7592
# Epoch 47 Batch 400 Loss 0.9834 Accuracy 0.7583
# Epoch 47 Batch 450 Loss 0.9850 Accuracy 0.7579
# Epoch 47 Batch 500 Loss 0.9866 Accuracy 0.7577
# Epoch 47 Batch 550 Loss 0.9879 Accuracy 0.7573
# Epoch 47 Batch 600 Loss 0.9900 Accuracy 0.7569
# Epoch 47 Batch 650 Loss 0.9925 Accuracy 0.7564
# Epoch 47 Batch 700 Loss 0.9968 Accuracy 0.7555
# Epoch 47 Batch 750 Loss 0.9993 Accuracy 0.7551
# Epoch 47 Batch 800 Loss 1.0022 Accuracy 0.7546
# Epoch 47 Loss 1.0030 Accuracy 0.7545
# Time taken for epoch 47: 92.64 secs
#
# Epoch 48 Batch 0 Loss 0.9430 Accuracy 0.7610
# Epoch 48 Batch 50 Loss 0.9576 Accuracy 0.7654
# Epoch 48 Batch 100 Loss 0.9426 Accuracy 0.7677
# Epoch 48 Batch 150 Loss 0.9474 Accuracy 0.7660
# Epoch 48 Batch 200 Loss 0.9515 Accuracy 0.7648
# Epoch 48 Batch 250 Loss 0.9594 Accuracy 0.7637
# Epoch 48 Batch 300 Loss 0.9615 Accuracy 0.7633
# Epoch 48 Batch 350 Loss 0.9664 Accuracy 0.7619
# Epoch 48 Batch 400 Loss 0.9701 Accuracy 0.7613
# Epoch 48 Batch 450 Loss 0.9738 Accuracy 0.7604
# Epoch 48 Batch 500 Loss 0.9755 Accuracy 0.7602
# Epoch 48 Batch 550 Loss 0.9781 Accuracy 0.7597
# Epoch 48 Batch 600 Loss 0.9814 Accuracy 0.7589
# Epoch 48 Batch 650 Loss 0.9848 Accuracy 0.7583
# Epoch 48 Batch 700 Loss 0.9879 Accuracy 0.7575
# Epoch 48 Batch 750 Loss 0.9911 Accuracy 0.7569
# Epoch 48 Batch 800 Loss 0.9939 Accuracy 0.7564
# Epoch 48 Loss 0.9942 Accuracy 0.7563
# Time taken for epoch 48: 92.54 secs
#
# Epoch 49 Batch 0 Loss 0.8483 Accuracy 0.7803
# Epoch 49 Batch 50 Loss 0.9330 Accuracy 0.7680
# Epoch 49 Batch 100 Loss 0.9477 Accuracy 0.7654
# Epoch 49 Batch 150 Loss 0.9463 Accuracy 0.7659
# Epoch 49 Batch 200 Loss 0.9477 Accuracy 0.7655
# Epoch 49 Batch 250 Loss 0.9525 Accuracy 0.7646
# Epoch 49 Batch 300 Loss 0.9558 Accuracy 0.7640
# Epoch 49 Batch 350 Loss 0.9604 Accuracy 0.7630
# Epoch 49 Batch 400 Loss 0.9621 Accuracy 0.7626
# Epoch 49 Batch 450 Loss 0.9640 Accuracy 0.7623
# Epoch 49 Batch 500 Loss 0.9648 Accuracy 0.7623
# Epoch 49 Batch 550 Loss 0.9673 Accuracy 0.7619
# Epoch 49 Batch 600 Loss 0.9718 Accuracy 0.7609
# Epoch 49 Batch 650 Loss 0.9750 Accuracy 0.7602
# Epoch 49 Batch 700 Loss 0.9787 Accuracy 0.7594
# Epoch 49 Batch 750 Loss 0.9814 Accuracy 0.7589
# Epoch 49 Batch 800 Loss 0.9842 Accuracy 0.7584
# Epoch 49 Loss 0.9853 Accuracy 0.7581
# Time taken for epoch 49: 92.05 secs
#
# Epoch 50 Batch 0 Loss 0.8331 Accuracy 0.7823
# Epoch 50 Batch 50 Loss 0.9215 Accuracy 0.7706
# Epoch 50 Batch 100 Loss 0.9302 Accuracy 0.7695
# Epoch 50 Batch 150 Loss 0.9354 Accuracy 0.7676
# Epoch 50 Batch 200 Loss 0.9417 Accuracy 0.7663
# Epoch 50 Batch 250 Loss 0.9464 Accuracy 0.7654
# Epoch 50 Batch 300 Loss 0.9480 Accuracy 0.7652
# Epoch 50 Batch 350 Loss 0.9494 Accuracy 0.7651
# Epoch 50 Batch 400 Loss 0.9528 Accuracy 0.7645
# Epoch 50 Batch 450 Loss 0.9548 Accuracy 0.7643
# Epoch 50 Batch 500 Loss 0.9581 Accuracy 0.7637
# Epoch 50 Batch 550 Loss 0.9606 Accuracy 0.7632
# Epoch 50 Batch 600 Loss 0.9635 Accuracy 0.7625
# Epoch 50 Batch 650 Loss 0.9668 Accuracy 0.7620
# Epoch 50 Batch 700 Loss 0.9697 Accuracy 0.7615
# Epoch 50 Batch 750 Loss 0.9733 Accuracy 0.7607
# Epoch 50 Batch 800 Loss 0.9757 Accuracy 0.7602
# Saving checkpoint for epoch 50 at ./checkpoints/train/ckpt-10
# Epoch 50 Loss 0.9763 Accuracy 0.7601
# Time taken for epoch 50: 93.09 secs
#
# Epoch 51 Batch 0 Loss 0.8142 Accuracy 0.8009
# Epoch 51 Batch 50 Loss 0.9234 Accuracy 0.7700
# Epoch 51 Batch 100 Loss 0.9296 Accuracy 0.7681
# Epoch 51 Batch 150 Loss 0.9333 Accuracy 0.7684
# Epoch 51 Batch 200 Loss 0.9392 Accuracy 0.7670
# Epoch 51 Batch 250 Loss 0.9411 Accuracy 0.7667
# Epoch 51 Batch 300 Loss 0.9435 Accuracy 0.7663
# Epoch 51 Batch 350 Loss 0.9471 Accuracy 0.7654
# Epoch 51 Batch 400 Loss 0.9483 Accuracy 0.7652
# Epoch 51 Batch 450 Loss 0.9527 Accuracy 0.7643
# Epoch 51 Batch 500 Loss 0.9557 Accuracy 0.7637
# Epoch 51 Batch 550 Loss 0.9576 Accuracy 0.7634
# Epoch 51 Batch 600 Loss 0.9595 Accuracy 0.7630
# Epoch 51 Batch 650 Loss 0.9614 Accuracy 0.7626
# Epoch 51 Batch 700 Loss 0.9657 Accuracy 0.7619
# Epoch 51 Batch 750 Loss 0.9683 Accuracy 0.7613
# Epoch 51 Batch 800 Loss 0.9713 Accuracy 0.7607
# Epoch 51 Loss 0.9723 Accuracy 0.7604
# Time taken for epoch 51: 93.14 secs
#
# Epoch 52 Batch 0 Loss 0.8605 Accuracy 0.7844
# Epoch 52 Batch 50 Loss 0.9103 Accuracy 0.7717
# Epoch 52 Batch 100 Loss 0.9056 Accuracy 0.7734
# Epoch 52 Batch 150 Loss 0.9152 Accuracy 0.7714
# Epoch 52 Batch 200 Loss 0.9197 Accuracy 0.7701
# Epoch 52 Batch 250 Loss 0.9277 Accuracy 0.7686
# Epoch 52 Batch 300 Loss 0.9318 Accuracy 0.7675
# Epoch 52 Batch 350 Loss 0.9355 Accuracy 0.7668
# Epoch 52 Batch 400 Loss 0.9393 Accuracy 0.7660
# Epoch 52 Batch 450 Loss 0.9429 Accuracy 0.7655
# Epoch 52 Batch 500 Loss 0.9459 Accuracy 0.7648
# Epoch 52 Batch 550 Loss 0.9472 Accuracy 0.7646
# Epoch 52 Batch 600 Loss 0.9500 Accuracy 0.7642
# Epoch 52 Batch 650 Loss 0.9532 Accuracy 0.7636
# Epoch 52 Batch 700 Loss 0.9563 Accuracy 0.7631
# Epoch 52 Batch 750 Loss 0.9592 Accuracy 0.7626
# Epoch 52 Batch 800 Loss 0.9615 Accuracy 0.7622
# Epoch 52 Loss 0.9616 Accuracy 0.7621
# Time taken for epoch 52: 92.08 secs
#
# Epoch 53 Batch 0 Loss 0.9700 Accuracy 0.7649
# Epoch 53 Batch 50 Loss 0.9163 Accuracy 0.7712
# Epoch 53 Batch 100 Loss 0.9168 Accuracy 0.7724
# Epoch 53 Batch 150 Loss 0.9212 Accuracy 0.7711
# Epoch 53 Batch 200 Loss 0.9231 Accuracy 0.7705
# Epoch 53 Batch 250 Loss 0.9283 Accuracy 0.7696
# Epoch 53 Batch 300 Loss 0.9295 Accuracy 0.7693
# Epoch 53 Batch 350 Loss 0.9313 Accuracy 0.7689
# Epoch 53 Batch 400 Loss 0.9362 Accuracy 0.7678
# Epoch 53 Batch 450 Loss 0.9386 Accuracy 0.7675
# Epoch 53 Batch 500 Loss 0.9406 Accuracy 0.7671
# Epoch 53 Batch 550 Loss 0.9428 Accuracy 0.7664
# Epoch 53 Batch 600 Loss 0.9460 Accuracy 0.7658
# Epoch 53 Batch 650 Loss 0.9479 Accuracy 0.7654
# Epoch 53 Batch 700 Loss 0.9515 Accuracy 0.7646
# Epoch 53 Batch 750 Loss 0.9551 Accuracy 0.7640
# Epoch 53 Batch 800 Loss 0.9575 Accuracy 0.7636
# Epoch 53 Loss 0.9575 Accuracy 0.7636
# Time taken for epoch 53: 92.64 secs
#
# Epoch 54 Batch 0 Loss 0.8820 Accuracy 0.7731
# Epoch 54 Batch 50 Loss 0.9086 Accuracy 0.7723
# Epoch 54 Batch 100 Loss 0.9069 Accuracy 0.7733
# Epoch 54 Batch 150 Loss 0.9100 Accuracy 0.7728
# Epoch 54 Batch 200 Loss 0.9130 Accuracy 0.7721
# Epoch 54 Batch 250 Loss 0.9180 Accuracy 0.7711
# Epoch 54 Batch 300 Loss 0.9192 Accuracy 0.7706
# Epoch 54 Batch 350 Loss 0.9216 Accuracy 0.7702
# Epoch 54 Batch 400 Loss 0.9249 Accuracy 0.7692
# Epoch 54 Batch 450 Loss 0.9301 Accuracy 0.7680
# Epoch 54 Batch 500 Loss 0.9333 Accuracy 0.7674
# Epoch 54 Batch 550 Loss 0.9342 Accuracy 0.7672
# Epoch 54 Batch 600 Loss 0.9355 Accuracy 0.7671
# Epoch 54 Batch 650 Loss 0.9380 Accuracy 0.7666
# Epoch 54 Batch 700 Loss 0.9409 Accuracy 0.7661
# Epoch 54 Batch 750 Loss 0.9448 Accuracy 0.7654
# Epoch 54 Batch 800 Loss 0.9481 Accuracy 0.7647
# Epoch 54 Loss 0.9488 Accuracy 0.7646
# Time taken for epoch 54: 92.52 secs
#
# Epoch 55 Batch 0 Loss 0.7918 Accuracy 0.8152
# Epoch 55 Batch 50 Loss 0.9030 Accuracy 0.7761
# Epoch 55 Batch 100 Loss 0.9110 Accuracy 0.7738
# Epoch 55 Batch 150 Loss 0.9157 Accuracy 0.7717
# Epoch 55 Batch 200 Loss 0.9122 Accuracy 0.7720
# Epoch 55 Batch 250 Loss 0.9145 Accuracy 0.7715
# Epoch 55 Batch 300 Loss 0.9171 Accuracy 0.7710
# Epoch 55 Batch 350 Loss 0.9205 Accuracy 0.7705
# Epoch 55 Batch 400 Loss 0.9228 Accuracy 0.7700
# Epoch 55 Batch 450 Loss 0.9247 Accuracy 0.7696
# Epoch 55 Batch 500 Loss 0.9263 Accuracy 0.7693
# Epoch 55 Batch 550 Loss 0.9287 Accuracy 0.7688
# ...
# Time taken for epoch 82: 92.86 secs
#
# Epoch 83 Batch 0 Loss 0.6737 Accuracy 0.8254
# Epoch 83 Batch 50 Loss 0.7546 Accuracy 0.8052
# Epoch 83 Batch 100 Loss 0.7668 Accuracy 0.8011
# Epoch 83 Batch 150 Loss 0.7693 Accuracy 0.8004
# Epoch 83 Batch 200 Loss 0.7742 Accuracy 0.7994
# Epoch 83 Batch 250 Loss 0.7785 Accuracy 0.7982
# Epoch 83 Batch 300 Loss 0.7810 Accuracy 0.7975
# Epoch 83 Batch 350 Loss 0.7847 Accuracy 0.7966
# Epoch 83 Batch 400 Loss 0.7861 Accuracy 0.7963
# Epoch 83 Batch 450 Loss 0.7882 Accuracy 0.7959
# Epoch 83 Batch 500 Loss 0.7907 Accuracy 0.7953
# Epoch 83 Batch 550 Loss 0.7942 Accuracy 0.7945
# Epoch 83 Batch 600 Loss 0.7951 Accuracy 0.7943
# Epoch 83 Batch 650 Loss 0.7983 Accuracy 0.7936
# Epoch 83 Batch 700 Loss 0.8013 Accuracy 0.7929
# Epoch 83 Batch 750 Loss 0.8046 Accuracy 0.7922
# Epoch 83 Batch 800 Loss 0.8070 Accuracy 0.7917
# Epoch 83 Loss 0.8070 Accuracy 0.7917
# Time taken for epoch 83: 92.57 secs
#
# Epoch 84 Batch 0 Loss 0.7255 Accuracy 0.8125
# Epoch 84 Batch 50 Loss 0.7575 Accuracy 0.8033
# Epoch 84 Batch 100 Loss 0.7629 Accuracy 0.8012
# Epoch 84 Batch 150 Loss 0.7662 Accuracy 0.8004
# Epoch 84 Batch 200 Loss 0.7731 Accuracy 0.7987
# Epoch 84 Batch 250 Loss 0.7765 Accuracy 0.7978
# Epoch 84 Batch 300 Loss 0.7779 Accuracy 0.7977
# Epoch 84 Batch 350 Loss 0.7804 Accuracy 0.7972
# Epoch 84 Batch 400 Loss 0.7815 Accuracy 0.7969
# Epoch 84 Batch 450 Loss 0.7863 Accuracy 0.7959
# Epoch 84 Batch 500 Loss 0.7892 Accuracy 0.7951
# Epoch 84 Batch 550 Loss 0.7929 Accuracy 0.7944
# Epoch 84 Batch 600 Loss 0.7958 Accuracy 0.7937
# Epoch 84 Batch 650 Loss 0.7991 Accuracy 0.7929
# Epoch 84 Batch 700 Loss 0.8014 Accuracy 0.7925
# Epoch 84 Batch 750 Loss 0.8037 Accuracy 0.7920
# Epoch 84 Batch 800 Loss 0.8056 Accuracy 0.7917
# Epoch 84 Loss 0.8063 Accuracy 0.7915
# Time taken for epoch 84: 92.47 secs
#
# Epoch 85 Batch 0 Loss 0.6851 Accuracy 0.8107
# Epoch 85 Batch 50 Loss 0.7581 Accuracy 0.8012
# Epoch 85 Batch 100 Loss 0.7603 Accuracy 0.8007
# Epoch 85 Batch 150 Loss 0.7613 Accuracy 0.8007
# Epoch 85 Batch 200 Loss 0.7635 Accuracy 0.8005
# Epoch 85 Batch 250 Loss 0.7683 Accuracy 0.7996
# Epoch 85 Batch 300 Loss 0.7727 Accuracy 0.7985
# Epoch 85 Batch 350 Loss 0.7748 Accuracy 0.7980
# Epoch 85 Batch 400 Loss 0.7779 Accuracy 0.7974
# Epoch 85 Batch 450 Loss 0.7795 Accuracy 0.7970
# Epoch 85 Batch 500 Loss 0.7818 Accuracy 0.7966
# Epoch 85 Batch 550 Loss 0.7848 Accuracy 0.7961
# Epoch 85 Batch 600 Loss 0.7886 Accuracy 0.7951
# Epoch 85 Batch 650 Loss 0.7923 Accuracy 0.7944
# Epoch 85 Batch 700 Loss 0.7952 Accuracy 0.7938
# Epoch 85 Batch 750 Loss 0.7973 Accuracy 0.7934
# Epoch 85 Batch 800 Loss 0.8001 Accuracy 0.7928
# Saving checkpoint for epoch 85 at ./checkpoints/train/ckpt-17
# Epoch 85 Loss 0.8006 Accuracy 0.7927
# Time taken for epoch 85: 92.98 secs
#
# Epoch 86 Batch 0 Loss 0.7490 Accuracy 0.8050
# Epoch 86 Batch 50 Loss 0.7675 Accuracy 0.7992
# Epoch 86 Batch 100 Loss 0.7619 Accuracy 0.8011
# Epoch 86 Batch 150 Loss 0.7638 Accuracy 0.8001
# Epoch 86 Batch 200 Loss 0.7672 Accuracy 0.7998
# Epoch 86 Batch 250 Loss 0.7716 Accuracy 0.7989
# Epoch 86 Batch 300 Loss 0.7746 Accuracy 0.7984
# Epoch 86 Batch 350 Loss 0.7790 Accuracy 0.7974
# Epoch 86 Batch 400 Loss 0.7820 Accuracy 0.7970
# Epoch 86 Batch 450 Loss 0.7839 Accuracy 0.7966
# Epoch 86 Batch 500 Loss 0.7850 Accuracy 0.7964
# Epoch 86 Batch 550 Loss 0.7874 Accuracy 0.7959
# Epoch 86 Batch 600 Loss 0.7894 Accuracy 0.7955
# Epoch 86 Batch 650 Loss 0.7914 Accuracy 0.7952
# Epoch 86 Batch 700 Loss 0.7946 Accuracy 0.7946
# Epoch 86 Batch 750 Loss 0.7973 Accuracy 0.7941
# Epoch 86 Batch 800 Loss 0.7993 Accuracy 0.7937
# Epoch 86 Loss 0.7998 Accuracy 0.7935
# Time taken for epoch 86: 92.75 secs
#
# Epoch 87 Batch 0 Loss 0.7397 Accuracy 0.8047
# Epoch 87 Batch 50 Loss 0.7529 Accuracy 0.8038
# Epoch 87 Batch 100 Loss 0.7579 Accuracy 0.8026
# Epoch 87 Batch 150 Loss 0.7624 Accuracy 0.8011
# Epoch 87 Batch 200 Loss 0.7655 Accuracy 0.8008
# Epoch 87 Batch 250 Loss 0.7675 Accuracy 0.8000
# Epoch 87 Batch 300 Loss 0.7704 Accuracy 0.7995
# Epoch 87 Batch 350 Loss 0.7739 Accuracy 0.7985
# Epoch 87 Batch 400 Loss 0.7757 Accuracy 0.7981
# Epoch 87 Batch 450 Loss 0.7786 Accuracy 0.7974
# Epoch 87 Batch 500 Loss 0.7814 Accuracy 0.7969
# Epoch 87 Batch 550 Loss 0.7833 Accuracy 0.7964
# Epoch 87 Batch 600 Loss 0.7861 Accuracy 0.7959
# Epoch 87 Batch 650 Loss 0.7882 Accuracy 0.7955
# Epoch 87 Batch 700 Loss 0.7907 Accuracy 0.7950
# Epoch 87 Batch 750 Loss 0.7931 Accuracy 0.7945
# Epoch 87 Batch 800 Loss 0.7957 Accuracy 0.7938
# Epoch 87 Loss 0.7963 Accuracy 0.7938
# Time taken for epoch 87: 92.78 secs
#
# Epoch 88 Batch 0 Loss 0.7688 Accuracy 0.7940
# Epoch 88 Batch 50 Loss 0.7552 Accuracy 0.8011
# Epoch 88 Batch 100 Loss 0.7569 Accuracy 0.8013
# Epoch 88 Batch 150 Loss 0.7598 Accuracy 0.8017
# Epoch 88 Batch 200 Loss 0.7618 Accuracy 0.8009
# Epoch 88 Batch 250 Loss 0.7654 Accuracy 0.7999
# Epoch 88 Batch 300 Loss 0.7682 Accuracy 0.7995
# Epoch 88 Batch 350 Loss 0.7709 Accuracy 0.7988
# Epoch 88 Batch 400 Loss 0.7731 Accuracy 0.7984
# Epoch 88 Batch 450 Loss 0.7742 Accuracy 0.7981
# Epoch 88 Batch 500 Loss 0.7760 Accuracy 0.7977
# Epoch 88 Batch 550 Loss 0.7782 Accuracy 0.7974
# Epoch 88 Batch 600 Loss 0.7807 Accuracy 0.7970
# Epoch 88 Batch 650 Loss 0.7833 Accuracy 0.7964
# Epoch 88 Batch 700 Loss 0.7866 Accuracy 0.7957
# Epoch 88 Batch 750 Loss 0.7890 Accuracy 0.7952
# Epoch 88 Batch 800 Loss 0.7920 Accuracy 0.7947
# Epoch 88 Loss 0.7926 Accuracy 0.7946
# Time taken for epoch 88: 92.79 secs
#
# Epoch 89 Batch 0 Loss 0.7655 Accuracy 0.8044
# Epoch 89 Batch 50 Loss 0.7589 Accuracy 0.8023
# Epoch 89 Batch 100 Loss 0.7513 Accuracy 0.8040
# Epoch 89 Batch 150 Loss 0.7519 Accuracy 0.8035
# Epoch 89 Batch 200 Loss 0.7569 Accuracy 0.8027
# Epoch 89 Batch 250 Loss 0.7603 Accuracy 0.8019
# Epoch 89 Batch 300 Loss 0.7655 Accuracy 0.8006
# Epoch 89 Batch 350 Loss 0.7679 Accuracy 0.8002
# Epoch 89 Batch 400 Loss 0.7701 Accuracy 0.7996
# Epoch 89 Batch 450 Loss 0.7717 Accuracy 0.7993
# Epoch 89 Batch 500 Loss 0.7750 Accuracy 0.7985
# Epoch 89 Batch 550 Loss 0.7778 Accuracy 0.7978
# Epoch 89 Batch 600 Loss 0.7812 Accuracy 0.7971
# Epoch 89 Batch 650 Loss 0.7831 Accuracy 0.7967
# Epoch 89 Batch 700 Loss 0.7859 Accuracy 0.7961
# Epoch 89 Batch 750 Loss 0.7883 Accuracy 0.7957
# Epoch 89 Batch 800 Loss 0.7903 Accuracy 0.7952
# Epoch 89 Loss 0.7907 Accuracy 0.7951
# Time taken for epoch 89: 91.96 secs
#
# Epoch 90 Batch 0 Loss 0.7199 Accuracy 0.8126
# Epoch 90 Batch 50 Loss 0.7317 Accuracy 0.8074
# Epoch 90 Batch 100 Loss 0.7431 Accuracy 0.8054
# Epoch 90 Batch 150 Loss 0.7485 Accuracy 0.8045
# Epoch 90 Batch 200 Loss 0.7536 Accuracy 0.8030
# Epoch 90 Batch 250 Loss 0.7597 Accuracy 0.8015
# Epoch 90 Batch 300 Loss 0.7611 Accuracy 0.8012
# Epoch 90 Batch 350 Loss 0.7654 Accuracy 0.8003
# Epoch 90 Batch 400 Loss 0.7681 Accuracy 0.7996
# Epoch 90 Batch 450 Loss 0.7696 Accuracy 0.7992
# Epoch 90 Batch 500 Loss 0.7709 Accuracy 0.7990
# Epoch 90 Batch 550 Loss 0.7728 Accuracy 0.7985
# Epoch 90 Batch 600 Loss 0.7751 Accuracy 0.7980
# Epoch 90 Batch 650 Loss 0.7776 Accuracy 0.7974
# Epoch 90 Batch 700 Loss 0.7807 Accuracy 0.7968
# Epoch 90 Batch 750 Loss 0.7834 Accuracy 0.7963
# Epoch 90 Batch 800 Loss 0.7867 Accuracy 0.7956
# Saving checkpoint for epoch 90 at ./checkpoints/train/ckpt-18
# Epoch 90 Loss 0.7867 Accuracy 0.7956
# Time taken for epoch 90: 93.49 secs
#
# Epoch 91 Batch 0 Loss 0.7504 Accuracy 0.8143
# Epoch 91 Batch 50 Loss 0.7458 Accuracy 0.8055
# Epoch 91 Batch 100 Loss 0.7430 Accuracy 0.8053
# Epoch 91 Batch 150 Loss 0.7473 Accuracy 0.8045
# Epoch 91 Batch 200 Loss 0.7543 Accuracy 0.8025
# Epoch 91 Batch 250 Loss 0.7582 Accuracy 0.8016
# Epoch 91 Batch 300 Loss 0.7604 Accuracy 0.8014
# Epoch 91 Batch 350 Loss 0.7624 Accuracy 0.8008
# Epoch 91 Batch 400 Loss 0.7652 Accuracy 0.8003
# Epoch 91 Batch 450 Loss 0.7668 Accuracy 0.7999
# Epoch 91 Batch 500 Loss 0.7699 Accuracy 0.7993
# Epoch 91 Batch 550 Loss 0.7720 Accuracy 0.7990
# Epoch 91 Batch 600 Loss 0.7741 Accuracy 0.7986
# Epoch 91 Batch 650 Loss 0.7761 Accuracy 0.7981
# Epoch 91 Batch 700 Loss 0.7774 Accuracy 0.7978
# Epoch 91 Batch 750 Loss 0.7801 Accuracy 0.7971
# Epoch 91 Batch 800 Loss 0.7825 Accuracy 0.7966
# Epoch 91 Loss 0.7826 Accuracy 0.7966
# Time taken for epoch 91: 91.79 secs
#
# Epoch 92 Batch 0 Loss 0.6088 Accuracy 0.8331
# Epoch 92 Batch 50 Loss 0.7336 Accuracy 0.8077
# Epoch 92 Batch 100 Loss 0.7399 Accuracy 0.8061
# Epoch 92 Batch 150 Loss 0.7456 Accuracy 0.8040
# Epoch 92 Batch 200 Loss 0.7487 Accuracy 0.8032
# Epoch 92 Batch 250 Loss 0.7526 Accuracy 0.8026
# Epoch 92 Batch 300 Loss 0.7548 Accuracy 0.8022
# Epoch 92 Batch 350 Loss 0.7579 Accuracy 0.8015
# Epoch 92 Batch 400 Loss 0.7612 Accuracy 0.8008
# Epoch 92 Batch 450 Loss 0.7628 Accuracy 0.8006
# Epoch 92 Batch 500 Loss 0.7648 Accuracy 0.8002
# Epoch 92 Batch 550 Loss 0.7668 Accuracy 0.7997
# Epoch 92 Batch 600 Loss 0.7707 Accuracy 0.7987
# Epoch 92 Batch 650 Loss 0.7716 Accuracy 0.7985
# Epoch 92 Batch 700 Loss 0.7745 Accuracy 0.7980
# Epoch 92 Batch 750 Loss 0.7772 Accuracy 0.7973
# Epoch 92 Batch 800 Loss 0.7789 Accuracy 0.7970
# Epoch 92 Loss 0.7794 Accuracy 0.7969
# Time taken for epoch 92: 92.36 secs
#
# Epoch 93 Batch 0 Loss 0.7217 Accuracy 0.8091
# Epoch 93 Batch 50 Loss 0.7259 Accuracy 0.8083
# Epoch 93 Batch 100 Loss 0.7320 Accuracy 0.8069
# Epoch 93 Batch 150 Loss 0.7347 Accuracy 0.8066
# Epoch 93 Batch 200 Loss 0.7415 Accuracy 0.8052
# Epoch 93 Batch 250 Loss 0.7475 Accuracy 0.8035
# Epoch 93 Batch 300 Loss 0.7513 Accuracy 0.8027
# Epoch 93 Batch 350 Loss 0.7528 Accuracy 0.8022
# Epoch 93 Batch 400 Loss 0.7557 Accuracy 0.8015
# Epoch 93 Batch 450 Loss 0.7586 Accuracy 0.8008
# Epoch 93 Batch 500 Loss 0.7611 Accuracy 0.8004
# Epoch 93 Batch 550 Loss 0.7632 Accuracy 0.8000
# Epoch 93 Batch 600 Loss 0.7675 Accuracy 0.7991
# Epoch 93 Batch 650 Loss 0.7692 Accuracy 0.7989
# Epoch 93 Batch 700 Loss 0.7715 Accuracy 0.7984
# Epoch 93 Batch 750 Loss 0.7742 Accuracy 0.7979
# Epoch 93 Batch 800 Loss 0.7772 Accuracy 0.7973
# Epoch 93 Loss 0.7778 Accuracy 0.7972
# Time taken for epoch 93: 92.30 secs
#
# Epoch 94 Batch 0 Loss 0.6787 Accuracy 0.8166
# Epoch 94 Batch 50 Loss 0.7147 Accuracy 0.8104
# Epoch 94 Batch 100 Loss 0.7300 Accuracy 0.8073
# Epoch 94 Batch 150 Loss 0.7386 Accuracy 0.8047
# Epoch 94 Batch 200 Loss 0.7429 Accuracy 0.8043
# Epoch 94 Batch 250 Loss 0.7453 Accuracy 0.8040
# Epoch 94 Batch 300 Loss 0.7480 Accuracy 0.8033
# Epoch 94 Batch 350 Loss 0.7502 Accuracy 0.8028
# Epoch 94 Batch 400 Loss 0.7527 Accuracy 0.8024
# Epoch 94 Batch 450 Loss 0.7547 Accuracy 0.8021
# Epoch 94 Batch 500 Loss 0.7557 Accuracy 0.8019
# Epoch 94 Batch 550 Loss 0.7578 Accuracy 0.8015
# Epoch 94 Batch 600 Loss 0.7610 Accuracy 0.8009
# Epoch 94 Batch 650 Loss 0.7636 Accuracy 0.8003
# Epoch 94 Batch 700 Loss 0.7665 Accuracy 0.7996
# Epoch 94 Batch 750 Loss 0.7702 Accuracy 0.7989
# Epoch 94 Batch 800 Loss 0.7730 Accuracy 0.7984
# Epoch 94 Loss 0.7734 Accuracy 0.7983
# Time taken for epoch 94: 92.15 secs
#
# Epoch 95 Batch 0 Loss 0.6483 Accuracy 0.8300
# Epoch 95 Batch 50 Loss 0.7245 Accuracy 0.8084
# Epoch 95 Batch 100 Loss 0.7299 Accuracy 0.8078
# Epoch 95 Batch 150 Loss 0.7353 Accuracy 0.8070
# Epoch 95 Batch 200 Loss 0.7420 Accuracy 0.8057
# Epoch 95 Batch 250 Loss 0.7458 Accuracy 0.8047
# Epoch 95 Batch 300 Loss 0.7451 Accuracy 0.8051
# Epoch 95 Batch 350 Loss 0.7485 Accuracy 0.8042
# Epoch 95 Batch 400 Loss 0.7496 Accuracy 0.8041
# Epoch 95 Batch 450 Loss 0.7522 Accuracy 0.8034
# Epoch 95 Batch 500 Loss 0.7541 Accuracy 0.8029
# Epoch 95 Batch 550 Loss 0.7561 Accuracy 0.8025
# Epoch 95 Batch 600 Loss 0.7583 Accuracy 0.8021
# Epoch 95 Batch 650 Loss 0.7600 Accuracy 0.8016
# Epoch 95 Batch 700 Loss 0.7628 Accuracy 0.8011
# Epoch 95 Batch 750 Loss 0.7655 Accuracy 0.8005
# Epoch 95 Batch 800 Loss 0.7690 Accuracy 0.7996
# Saving checkpoint for epoch 95 at ./checkpoints/train/ckpt-19
# Epoch 95 Loss 0.7689 Accuracy 0.7997
# Time taken for epoch 95: 93.66 secs
#
# Epoch 96 Batch 0 Loss 0.6872 Accuracy 0.8237
# Epoch 96 Batch 50 Loss 0.7183 Accuracy 0.8105
# Epoch 96 Batch 100 Loss 0.7246 Accuracy 0.8097
# Epoch 96 Batch 150 Loss 0.7310 Accuracy 0.8082
# Epoch 96 Batch 200 Loss 0.7337 Accuracy 0.8076
# Epoch 96 Batch 250 Loss 0.7378 Accuracy 0.8064
# Epoch 96 Batch 300 Loss 0.7415 Accuracy 0.8052
# Epoch 96 Batch 350 Loss 0.7448 Accuracy 0.8042
# Epoch 96 Batch 400 Loss 0.7488 Accuracy 0.8034
# Epoch 96 Batch 450 Loss 0.7513 Accuracy 0.8027
# Epoch 96 Batch 500 Loss 0.7534 Accuracy 0.8022
# Epoch 96 Batch 550 Loss 0.7555 Accuracy 0.8018
# Epoch 96 Batch 600 Loss 0.7581 Accuracy 0.8012
# Epoch 96 Batch 650 Loss 0.7594 Accuracy 0.8008
# Epoch 96 Batch 700 Loss 0.7623 Accuracy 0.8002
# Epoch 96 Batch 750 Loss 0.7649 Accuracy 0.7996
# Epoch 96 Batch 800 Loss 0.7670 Accuracy 0.7993
# Epoch 96 Loss 0.7678 Accuracy 0.7991
# Time taken for epoch 96: 92.86 secs
#
# Epoch 97 Batch 0 Loss 0.7751 Accuracy 0.7941
# Epoch 97 Batch 50 Loss 0.7267 Accuracy 0.8088
# Epoch 97 Batch 100 Loss 0.7349 Accuracy 0.8069
# Epoch 97 Batch 150 Loss 0.7354 Accuracy 0.8064
# Epoch 97 Batch 200 Loss 0.7385 Accuracy 0.8057
# Epoch 97 Batch 250 Loss 0.7428 Accuracy 0.8049
# Epoch 97 Batch 300 Loss 0.7424 Accuracy 0.8050
# Epoch 97 Batch 350 Loss 0.7443 Accuracy 0.8045
# Epoch 97 Batch 400 Loss 0.7478 Accuracy 0.8035
# Epoch 97 Batch 450 Loss 0.7501 Accuracy 0.8029
# Epoch 97 Batch 500 Loss 0.7519 Accuracy 0.8024
# Epoch 97 Batch 550 Loss 0.7535 Accuracy 0.8022
# Epoch 97 Batch 600 Loss 0.7562 Accuracy 0.8016
# Epoch 97 Batch 650 Loss 0.7589 Accuracy 0.8010
# Epoch 97 Batch 700 Loss 0.7615 Accuracy 0.8004
# Epoch 97 Batch 750 Loss 0.7640 Accuracy 0.7999
# Epoch 97 Batch 800 Loss 0.7665 Accuracy 0.7993
# Epoch 97 Loss 0.7668 Accuracy 0.7992
# Time taken for epoch 97: 93.50 secs
#
# Epoch 98 Batch 0 Loss 0.6650 Accuracy 0.8323
# Epoch 98 Batch 50 Loss 0.7169 Accuracy 0.8115
# Epoch 98 Batch 100 Loss 0.7225 Accuracy 0.8097
# Epoch 98 Batch 150 Loss 0.7252 Accuracy 0.8089
# Epoch 98 Batch 200 Loss 0.7303 Accuracy 0.8078
# Epoch 98 Batch 250 Loss 0.7350 Accuracy 0.8065
# Epoch 98 Batch 300 Loss 0.7385 Accuracy 0.8060
# Epoch 98 Batch 350 Loss 0.7405 Accuracy 0.8054
# Epoch 98 Batch 400 Loss 0.7427 Accuracy 0.8051
# Epoch 98 Batch 450 Loss 0.7455 Accuracy 0.8045
# Epoch 98 Batch 500 Loss 0.7469 Accuracy 0.8042
# Epoch 98 Batch 550 Loss 0.7474 Accuracy 0.8042
# Epoch 98 Batch 600 Loss 0.7514 Accuracy 0.8032
# Epoch 98 Batch 650 Loss 0.7542 Accuracy 0.8025
# Epoch 98 Batch 700 Loss 0.7570 Accuracy 0.8018
# Epoch 98 Batch 750 Loss 0.7591 Accuracy 0.8014
# Epoch 98 Batch 800 Loss 0.7626 Accuracy 0.8007
# Epoch 98 Loss 0.7633 Accuracy 0.8005
# Time taken for epoch 98: 91.76 secs
#
# Epoch 99 Batch 0 Loss 0.7128 Accuracy 0.8092
# Epoch 99 Batch 50 Loss 0.7252 Accuracy 0.8083
# Epoch 99 Batch 100 Loss 0.7239 Accuracy 0.8083
# Epoch 99 Batch 150 Loss 0.7238 Accuracy 0.8079
# Epoch 99 Batch 200 Loss 0.7291 Accuracy 0.8066
# Epoch 99 Batch 250 Loss 0.7320 Accuracy 0.8062
# Epoch 99 Batch 300 Loss 0.7327 Accuracy 0.8064
# Epoch 99 Batch 350 Loss 0.7367 Accuracy 0.8058
# Epoch 99 Batch 400 Loss 0.7393 Accuracy 0.8051
# Epoch 99 Batch 450 Loss 0.7415 Accuracy 0.8048
# Epoch 99 Batch 500 Loss 0.7440 Accuracy 0.8042
# Epoch 99 Batch 550 Loss 0.7467 Accuracy 0.8036
# Epoch 99 Batch 600 Loss 0.7483 Accuracy 0.8033
# Epoch 99 Batch 650 Loss 0.7507 Accuracy 0.8029
# Epoch 99 Batch 700 Loss 0.7531 Accuracy 0.8023
# Epoch 99 Batch 750 Loss 0.7563 Accuracy 0.8017
# Epoch 99 Batch 800 Loss 0.7592 Accuracy 0.8011
# Epoch 99 Loss 0.7595 Accuracy 0.8010
# Time taken for epoch 99: 92.76 secs
#
# Epoch 100 Batch 0 Loss 0.6465 Accuracy 0.8379
# Epoch 100 Batch 50 Loss 0.7164 Accuracy 0.8105
# Epoch 100 Batch 100 Loss 0.7132 Accuracy 0.8115
# Epoch 100 Batch 150 Loss 0.7194 Accuracy 0.8098
# Epoch 100 Batch 200 Loss 0.7268 Accuracy 0.8077
# Epoch 100 Batch 250 Loss 0.7306 Accuracy 0.8070
# Epoch 100 Batch 300 Loss 0.7347 Accuracy 0.8061
# Epoch 100 Batch 350 Loss 0.7354 Accuracy 0.8059
# Epoch 100 Batch 400 Loss 0.7388 Accuracy 0.8052
# Epoch 100 Batch 450 Loss 0.7428 Accuracy 0.8043
# Epoch 100 Batch 500 Loss 0.7433 Accuracy 0.8042
# Epoch 100 Batch 550 Loss 0.7458 Accuracy 0.8038
# Epoch 100 Batch 600 Loss 0.7485 Accuracy 0.8033
# Epoch 100 Batch 650 Loss 0.7512 Accuracy 0.8027
# Epoch 100 Batch 700 Loss 0.7529 Accuracy 0.8024
# Epoch 100 Batch 750 Loss 0.7560 Accuracy 0.8017
# Epoch 100 Batch 800 Loss 0.7580 Accuracy 0.8014
# Saving checkpoint for epoch 100 at ./checkpoints/train/ckpt-20
# Epoch 100 Loss 0.7582 Accuracy 0.8013
# Time taken for epoch 100: 93.51 secs

# %%
class Translator(tf.Module):
  def __init__(self, tokenizers, transformer):
    self.tokenizers = tokenizers
    self.transformer = transformer

  def __call__(self, sentence, max_length=20):
    # input sentence is portuguese, hence adding the start and end token
    assert isinstance(sentence, tf.Tensor)
    if len(sentence.shape) == 0:
      sentence = sentence[tf.newaxis]

    sentence = self.tokenizers.pt.tokenize(sentence).to_tensor()
    
    encoder_input = sentence

    # as the target is english, the first token to the transformer should be the
    # english start token.
    start_end = self.tokenizers.en.tokenize([''])[0]
    start = start_end[0][tf.newaxis]
    end = start_end[1][tf.newaxis]

    # `tf.TensorArray` is required here (instead of a python list) so that the
    # dynamic-loop can be traced by `tf.function`.
    output_array = tf.TensorArray(dtype=tf.int64, size=0, dynamic_size=True)
    output_array = output_array.write(0, start)
    
    for i in tf.range(max_length):
      output = tf.transpose(output_array.stack())
      predictions, _ = self.transformer([encoder_input, output], training=False)
      
      # select the last token from the seq_len dimension
      predictions = predictions[:, -1:, :]  # (batch_size, 1, vocab_size)

      predicted_id = tf.argmax(predictions, axis=-1)

      # concatentate the predicted_id to the output which is given to the decoder
      # as its input.
      output_array = output_array.write(i+1, predicted_id[0])

      if predicted_id == end:
        break

    output = tf.transpose(output_array.stack())
    # output.shape (1, tokens)
    text = tokenizers.en.detokenize(output)[0]  # shape: ()

    tokens = tokenizers.en.lookup(output)[0]

    # `tf.function` prevents us from using the attention_weights that were
    # calculated on the last iteration of the loop. So recalculate them outside
    # the loop.
    _, attention_weights = self.transformer([encoder_input, output[:,:-1]], training=False)

    return text, tokens, attention_weights

# %%
translator = Translator(tokenizers, transformer)

#helper function for testing examples
def print_translation(sentence, tokens, ground_truth):
  print(f'{"Input:":15s}: {sentence}')
  print(f'{"Prediction":15s}: {tokens.numpy().decode("utf-8")}')
  print(f'{"Ground truth":15s}: {ground_truth}')

# %%
sentence = "este é um problema que temos que resolver."
ground_truth = "this is a problem we have to solve ."

translated_text, translated_tokens, attention_weights = translator(
    tf.constant(sentence))
print_translation(sentence, translated_text, ground_truth)
print()

sentence = "vou então muito rapidamente partilhar convosco algumas histórias de algumas coisas mágicas que aconteceram."
ground_truth = "so i \'ll just share with you some stories very quickly of some magical things that have happened ."

translated_text, translated_tokens, attention_weights = translator(
    tf.constant(sentence))
print_translation(sentence, translated_text, ground_truth)
# Out:
# Input:         : este é um problema que temos que resolver.
# Prediction     : this is a problem that we need to solve .
# Ground truth   : this is a problem we have to solve .
#
# Input:         : vou então muito rapidamente partilhar convosco algumas histórias de algumas coisas mágicas que aconteceram.
# Prediction     : so i ' ll get very quickly to share with you some magical stories that had happened .
# Ground truth   : so i 'll just share with you some stories very quickly of some magical things that have happened .
